# %%
import random
import math
import copy

# %% [markdown]
# # MY IMCRO

# %%
# Initialization

# %% [markdown]
# # Molecule Class

# %%
class MoleCule:
    def __init__(self, structure,supersequence):
        self.pe = 0
        self.ke = 0
        self.opt = 9999999
        self.num_of_hits = 0
        self.structure = copy.deepcopy(structure)
        self.supersequence = copy.deepcopy(supersequence)

    def update(self):
        """
        If this molecule has a lower energy, reset num_of_hits.
        """
        if self.pe < self.opt:
            self.opt = self.pe
            self.num_of_hits = 0
    def __str__(self):
        reVal = ''
        for i in self.structure:
            reVal+=str(i)+" "
        
        for i in self.supersequence:
            reVal+=str(i)+" "
        return reVal

# %% [markdown]
# # Initialization

# %%
def insert_symbol(src_string,inserted_string,pos):
    return ''.join(src_string[:pos] + inserted_string + src_string[pos:])
# Given set of strings and population size for SCS problem
def supersequence_generate(set_of_strings):

    '''
        Make a copy of the set_of_strings parameter for maintaining the original 
        set
    '''
    copied_set_of_strings = copy.deepcopy(set_of_strings)
    supersequence = ''.join(copied_set_of_strings.pop(random.randint(0,len(set_of_strings)-1)))

    for i in range(len(copied_set_of_strings)):
        # print("i = ",i)
        counter = 0
        for j in copied_set_of_strings[i]:
            inserted_pos = random.randint(counter,len(supersequence))
            # print("j and counter and supersequence length and inserted index",j," ",counter," ",len(supersequence)," ",inserted_pos)
            if inserted_pos == len(supersequence) or j != supersequence[inserted_pos]:
                supersequence=insert_symbol(supersequence,j,inserted_pos)
            counter = inserted_pos +1
            # print(supersequence)

    return supersequence

# supersequence_generate(['acg', 'cat', 'gtt','tgc'])

def population_generation(pop_size,set_of_strings):
    l=[]
    for i in range(pop_size):
        l.append(supersequence_generate(set_of_strings))
    return l


# Generate many supersequence with popsize = 10 and given set of strings
# initial_population =  population_generation(10,['acg', 'cat', 'gtt','tgc'])
# initial_population

# %%
def encoding_population(initial_population):
    dict = {
        'a' : 0,
        'c' : 1,
        'g' : 2,
        't' : 3
    }
    l=[]
    for i in initial_population:
        k=''
        for j in i:
            k+=str(dict[j])
        l.append(k)
    return l
# encoding_population(initial_population)

# %%
def createMolecule(string):
    l=[]
    for i in string:
        l.append(int(i))
    return MoleCule(structure=[random.random(), random.random()],supersequence=l)

# %%
def initialization(pop_size,set_of_strings):
    initial_population =  population_generation(pop_size,set_of_strings)
    encoded_population = encoding_population(initial_population)
    l=[]
    for i in encoded_population:
        l.append(createMolecule(i))
    return l

molecules=initialization(20,['acg', 'cat', 'gtt','tgc'])

# %%
class Operators():
    
    # OnWall Ineffective Colision
    def OnWall (self,molecule):
        print("On Wall: ",molecule)
        '''
        Object: 
        -  This focuses on instances of molecules colliding with container walls, resulting in structural transformations.
        - A "one-difference operator" is used to make a single change in the molecule's composition to achieve this.

        Input:
        - molecule (list): the input molecule and it represent by list

        Output:
        - The method returns a new list. 
        '''
        #Initial
        m = molecule[:] 
        v_low = 0
        v_upper = 3   
        i = random.randint(0, len(molecule)-1)
        j = random.randint(v_low, v_upper)

        if (molecule[i] + j <= v_upper):    
            m[i] = molecule[i] + j
        else:
            m[i] = molecule[i] - j
        
        #Test     
        # print(i, j)
        return m

    # Intermolecular Ineffective Colision
    def Intermolecular(self,molecule1, molecule2):
        print("Intermolecule: ",molecule1," Length: ",len(molecule1)," ",molecule2," Length: ",len(molecule2))
        '''
        Object: 
        -  The purpose is to introduce significant changes to enhance local search capabilities and prevent getting stuck in local optimization by promoting diversity.
        - A crossover operator is used in genetic or evolutionary algorithms for optimization. It selects two molecules from the population and uses a two-step mechanism to generate two new solutions.
        - It is a two step process: the first step is to crossover between two molecules, and the second step is to crossover inside the molecule itself

        Input:
        - molecule (list): the input molecule and it represent by list

        Output:
        - The method returns a tuple (m1, m2), where m1 and m2 are the two molecules and m1, m2 are also list. 
        '''
        #Initial 
        # Length of molecule
        # print(molecule1,molecule2)
        length1 = len(molecule1)
        length2 = len(molecule2)
    
        #Two new molecule in first crossover
        # Copy 2 molecules
        m1 = molecule1.copy()
        m2 = molecule2.copy()
        #Two new molecule in second crossover
        m11 = [0] * length1
        m22 = [0] * length2
        
        limit = min(length2, length1) 
        
        #Random numbers x1, x2 generation
        x1 = random.randint(0, limit-2)
        x2 = random.randint(x1+1, limit-1)
    
        # Randormly choose form molecule1 or molecule2
        # Crossover 1
        for i in range(0,limit):
            if (i<x1 or i>x2):  #if odd segments
                m1[i] = molecule1[i]
                m2[i] = molecule2[i]
            elif (i>=x1 and x2>=i): # if even segment
                m1[i] = molecule2[i]
                m2[i] = molecule1[i]
        
        # Crossover 2
        # Crossover 2 for molecule m1
        for j in range(0,length1):
            if (j < x1):  #if odd segments
                m11[length1 - x1 + j] = m1[j]
                
            elif (j>=x1 and x2>=j): # if even segment
                m11[length1 - x1 - x2 + j - 1] = m1[j]
            else:
                m11[j - x2-1] = m1[j]
        
        # Crossover 2 for molecule m2
        for j in range(0,length2):
            if (j < x1):  #if odd segments
                m22[length2 - x1 + j] = m2[j]
            elif (j>=x1 and x2>=j): # if even segment
                m22[length2 - x1 - x2 + j- 1] = m2[j]
            else:
                m22[j - x2-1] = m2[j]
        
        #Test
        
        # print(limit)
        # print(x1, x2)
        # print(m1)
        # print(m2)
        print(" After Intermolecule: ",m11," ",m22)
        return m11,m22
    
    # Decomposition
    def Decomposition(self, molecule):
        print("Decomposition")
        '''
        Object: 
        - The decomposition involves randomly selecting two numbers 'a' and 'b', and then splitting the input molecule into two new molecules, 'm1' and 'm2', based on the selected numbers. 
        - The negative number −a is used for shifting to the left a steps. 
        - The positive number j is used for shifting to the right j steps.

        Input:
        - molecule (list): the input molecule and it represent by list

        Output:
        - The method returns a tuple (m1, m2), where m1 and m2 are the two molecules and m1, m2 are also list. 
        '''
        # Step 1: Select two numbers a and b randomly
        a = random.randint(-len(molecule), 0)
        b = random.randint(0, len(molecule))
        
        # Initialize m1 and m2
        m1 = [0] * len(molecule)
        m2 = [0] * len(molecule)

        # Step 2: Decomposition of molecule into m1
        for i in range(len(molecule)):
            if i + 1 <= -a:
                m1[len(molecule) - (-a) + i] = molecule[i]
            else:
                m1[i - (-a)] = molecule[i]

        # Step 3: Decomposition of molecule into m2
        for j in range(len(molecule)):
            if j + 1 <= len(molecule) - b:
                m2[j + b] = molecule[j]
            else:
                m2[j - len(molecule) + b] = molecule[j]
                
        #Test
        # print(molecule)
        # print(a, b)
        
        return m1, m2

    # Synthesis
    def Synthesis(self, molecule1, molecule2):
        print("Systhesis")
        """
        Generates a new list by combining two input lists in a way that preserves the frequency of the symbols used in each input list.

        Input:
        - molecule1 (list): The first input list.
        - molecule2 (list): The second input list.

        Output:
        - The method returns a new list. 
        """
        # Generate dictionaries for the frequencies of the symbols used in each input list.
        array1 = {}
        for symbol in molecule1:
            if symbol not in array1:
                array1[symbol] = 0
            array1[symbol] += 1

        array2 = {}
        for symbol in molecule2:
            if symbol not in array2:
                array2[symbol] = 0
            array2[symbol] += 1

        # Initialize the output list.
        length1 = len(molecule1)
        length2 = len(molecule2)
        limit = min(length1, length2)
        
        if(length1 < length2):
            m_prime = molecule2.copy()
        else:
            m_prime = molecule1.copy()

        # Iterate over the symbols in the first input list.
        for i in range(limit):
            symbol1 = molecule1[i]
            symbol2 = molecule2[i]

            frequency_in_array1 = array1.get(symbol1, 0)
            frequency_in_array2 = array2.get(symbol2, 0)

            if frequency_in_array1 >= frequency_in_array2:
                m_prime[i] = symbol1
            # Otherwise, add the symbol from the second input list to the output list.
            else:
                m_prime[i] = symbol2
        #test
        
        # print(molecule1)
        # print(molecule2)
        # print(array1)
        # print(array2)
        
        return m_prime

# %%
# Iteration
class IMCRO():
    optimal = None
    moleColl = 0.2
    alpha = random.randint(10, 100)
    beta = random.randint(10, 100)
    KELossRate = 0.6
    init_ke = 100
    buffer = 0
    pop=[]
    ops = None

    def __init__(self,pop) -> None:
        self.pop=pop
        self.ops = Operators()

        for mol in self.pop:
            # You should implement this function in your derived class
            mol.pe = self.fit_func(mol)
            mol.ke = self.init_ke
            mol.update()
            if self.optimal is None:
                self.optimal = copy.deepcopy(mol)
            elif mol.pe < self.optimal.pe:
                self.optimal = copy.deepcopy(mol)
    
    def run(self):
        i=0
        while i!=1000:
            i+=1
            t = random.random()
            if t > self.moleColl or len(self.pop) < 2:
                self.uni_moleReact()
            else :
                self.inter_moleReact()
    
    def update(self, m):
        """
        If m is the current optimal solution, save it to the optimal.
        """
        if m.pe < self.optimal.pe:
            self.optimal = copy.deepcopy(m)

    def uni_moleReact(self):
        m = random.choice(self.pop)
        if m.num_of_hits > self.alpha:
            self.decomposition(m)
        else :
            self.on_wall(m)

    def inter_moleReact(self):
        m1 , m2 = random.sample(self.pop,2)
        if m1.ke <= self.beta and m2.ke <= self.beta:
            self.ops.Synthesis(m1.supersequence,m2.supersequence)
        else :
            self.ops.Intermolecular(m1.supersequence,m2.supersequence)
    
    def decomposition(self,m):
        m.num_of_hits += 1

        # You should implement this function in your derived class
        new1, new2 = self.dec(m)
        new1.pe = self.fit_func(new1)
        new2.pe = self.fit_func(new2)
        tmp = m.pe + m.ke - new1.pe - new2.pe
        if tmp >= 0 or tmp + self.buffer >= 0:
            if tmp >= 0:
                q = random.random()
                new1.ke = tmp * q
                new2.ke = tmp * (1 - q)
            else:
                new1.ke = (tmp + self.buffer) * random.random() * random.random()
                new2.ke = (tmp + self.buffer - new1.ke) * random.random() * random.random()
                self.buffer = self.buffer + tmp - new1.ke - new2.ke
            new1.update()
            new2.update()
            self.pop.remove(m)
            self.pop.append(new1)
            self.pop.append(new2)
            self.update(new1)
            self.update(new2)
    def on_wall(self, m):
        m.num_of_hits += 1
        # You should implement this function in your derived class
        new = self.wall(m)
        new.pe = self.fit_func(new)
        tmp = m.pe + m.ke - new.pe
        if tmp >= 0:
            q = random.uniform(self.KELossRate, 1)
            new.ke = tmp * q
            new.update()
            self.buffer += tmp * (1 - q)
            self.pop.remove(m)
            self.pop.append(new)
            self.update(new)
    def interaction(self, m1, m2):
        m1.num_of_hits += 1
        m2.num_of_hits += 1

        # You should implement this function in your derived class
        new1, new2 = self.inter(m1, m2)
        new1.pe = self.fit_func(new1)
        new2.pe = self.fit_func(new2)
        tmp = m1.pe + m2.pe + m1.ke + m2.ke - new1.pe - new2.pe
        if tmp >= 0:
            q = random.random()
            new1.ke = tmp * q
            new2.ke = tmp * (1 - q)
            new1.update()
            new2.update()
            self.pop.remove(m1)
            self.pop.remove(m2)
            self.pop.append(new1)
            self.pop.append(new2)
            self.update(new1)
            self.update(new2)

    def synthesis(self, m1, m2):
        m1.num_of_hits += 1
        m2.num_of_hits += 1

        # You should implement this function in your derived class
        new = self.syn(m1, m2)
        new.pe = self.fit_func(new)
        tmp = m1.pe + m2.pe + m1.ke + m2.ke - new.pe
        if tmp >= 0:
            new.ke = tmp
            new.update()
            self.pop.remove(m1)
            self.pop.remove(m2)
            self.pop.append(new)
            self.update(new)

# %%
class MYIMCRO(IMCRO):
    def __init__(self, pop) -> None:
        super().__init__(pop)
    def fit_func(self, m):
            return math.sin(m.structure[0]) + math.cos(m.structure[1])
    def dec(self, m):
        new1 = copy.deepcopy(m)
        new2 = copy.deepcopy(m)
        new1.supersequence,new2.supersequence = self.ops.Decomposition(m.supersequence)
        new1.structure[0] += random.random()
        new2.structure[1] += random.random()
        return [new1, new2]
    
    def wall(self, m):
        new = copy.deepcopy(m)
        new.structure[0], new.structure[1] = new.structure[1], new.structure[0]
        new.supersequence = self.ops.OnWall(m.supersequence)
        return new
    
    def inter(self, m1, m2):
        new1 = copy.deepcopy(m1)
        new2 = copy.deepcopy(m2)
        new1.supersequence,new2.supersequence = self.ops.Intermolecular(m1.supersequence,m2.supersequence)
        new1.structure[0] = m2.structure[0]
        new1.structure[1] = m1.structure[1]
        new2.structure[0] = m1.structure[0]
        new2.structure[1] = m2.structure[1]
        return [new1, new2]
    def syn(self, m1, m2):
        new = copy.deepcopy(m1)
        new.supersequence = self.ops.Synthesis(m1.supersequence,m2.supersequence)
        if random.random() < 0.5:
            new.structure[0] = m2.structure[0]
        else:
            new.structure[1] = m2.structure[1]
        return new

# %%
initial = initialization(20,['acg', 'cat', 'gtt','tgc'])
myimcro = MYIMCRO(initial)
myimcro.run()
# Out:
# On Wall:  [0, 2, 3, 3, 1, 1, 2, 3, 2, 0, 3, 1]
# On Wall:  [1, 0, 0, 3, 2, 1, 3, 3, 3, 2, 2, 1]
# On Wall:  [2, 3, 1, 0, 1, 2, 0, 3, 2, 1]
# On Wall:  [1, 3, 0, 1, 2, 2, 3, 3, 1]
# On Wall:  [2, 1, 1, 0, 1, 2, 0, 3, 2, 1]
# On Wall:  [0, 2, 3, 1, 1, 1, 2, 3, 2, 0, 3, 1]
# On Wall:  [2, 3, 3, 2, 1, 0, 3, 3, 0, 1, 2]
# Intermolecule:  [0, 1, 2, 0, 3, 3, 1, 2, 3, 1]  Length:  10   [2, 0, 1, 2, 1, 3, 0, 3, 2, 1, 3]  Length:  11
#  After Intermolecule:  [3, 2, 1, 0, 1, 2, 0, 3, 3, 1]   [3, 2, 3, 1, 2, 0, 1, 2, 1, 3, 0]
# On Wall:  [0, 1, 2, 1, 0, 3, 2, 3, 3, 2, 1]
# On Wall:  [0, 1, 2, -2, 0, 3, 2, 3, 3, 2, 1]
# On Wall:  [1, 2, 0, 1, 2, 2, 3, 3, 1]
# On Wall:  [1, 2, 0, 3, 2, 1, 3, 3, 3, 2, 2, 1]
# On Wall:  [2, 0, 1, 2, 1, 3, 0, 3, 2, 1, 3]
# On Wall:  [2, 1, 0, 3, 3, 0, 1, 3, 2, 1, 3, 2]
# On Wall:  [1, 2, 0, 3, 2, 1, 3, 3, 3, 2, 2, 1]
# On Wall:  [1, 0, 2, 1, 2, 3, 3, 2, 1, 0, 3]
# Intermolecule:  [1, 2, 0, 3, 2, 1, 3, 3, 3, 2, 2, -2]  Length:  12   [2, 3, 3, 0, 3, 1, 2, 1, 2, 1, 0, 3]  Length:  12
#  After Intermolecule:  [2, 2, -2, 2, 1, 2, 1, 2, 0, 3, 2, 1]   [1, 0, 3, 3, 3, 3, 2, 3, 3, 0, 3, 1]
# On Wall:  [0, 2, 3, 1, 2, 1, 2, 3, 2, 0, 3, 1]
# Intermolecule:  [0, 1, 2, -2, 0, 3, 2, 3, 3, 2, 1]  Length:  11   [0, 2, 3, 1, 2, 1, 2, 3, 2, 0, 2, 1]  Length:  12
#  After Intermolecule:  [2, 1, 2, 3, 2, 0, 2, 0, 1, 2, -2]   [1, 0, 3, 2, 3, 3, 2, 1, 0, 2, 3, 1]
# On Wall:  [2, 3, 3, 0, 3, 1, 2, 1, 2, 1, 0, 3]
# On Wall:  [1, 0, -1, 1, 2, 3, 3, 2, 1, 0, 3]
# On Wall:  [1, 3, 0, 0, 2, 2, 3, 1, 1, 2, 3, 3]
# On Wall:  [1, 2, 0, 1, 2, 2, 2, 3, 1]
# On Wall:  [2, 1, 0, 3, 3, 2, 1, 3, 2, 1, 3, 2]
# On Wall:  [0, 1, 2, 0, 3, 3, 1, 2, 3, 1]
# On Wall:  [0, 1, 2, -2, 0, 3, 2, 3, 3, 2, 1]
# On Wall:  [0, 3, 3, 2, 1, 0, 3, 3, 0, 1, 2]
# On Wall:  [2, 0, 1, 1, 2, 3, 3, 3, 0, 3, 2, 1]
# On Wall:  [0, 2, 3, 1, 2, 1, 2, 3, 2, 0, 2, 1]
# Intermolecule:  [2, 1, 1, 0, -2, 2, 0, 3, 2, 1]  Length:  10   [3, 0, 1, 2, 2, 3, 3, 0, 1, 3]  Length:  10
#  After Intermolecule:  [1, 3, 0, 1, 2, 2, 3, 3, 0, 1]   [3, 2, 1, 1, 0, -2, 2, 0, 3, 2]
# On Wall:  [2, 1, 1, 0, -2, 2, 0, 3, 2, 1]
# On Wall:  [1, 2, 0, 3, 2, 1, 3, 3, 3, 2, 2, -2]
# On Wall:  [0, 2, 1, 1, 2, 1, 2, 3, 2, 0, 2, 1]
# On Wall:  [2, 3, 0, 3, 1, 2, 1, 0, 3, 3, 2, 1]
# On Wall:  [1, 2, 1, 1, 2, 2, 2, 3, 1]
# On Wall:  [0, 2, 1, 3, 2, 1, 1, 0, 3, 3]
# Intermolecule:  [1, 0, 3, 3, 2, 1, 2, 1, 2, 3, 3]  Length:  11   [0, 2, 1, 1, 2, 1, 2, 3, 2, 0, 2, 1]  Length:  12
#  After Intermolecule:  [2, 3, 3, 2, 1, 2, 3, 1, 0, 3, 3]   [2, 0, 2, 1, 2, 1, 2, 1, 0, 2, 1, 1]
# On Wall:  [1, 2, -2, 1, 2, 2, 2, 3, 1]
# On Wall:  [2, 0, 1, 2, 1, 3, 0, 0, 2, 1, 3]
# On Wall:  [2, 0, 1, 2, 1, 3, 0, 0, 2, 1, 3]
# On Wall:  [0, 1, 3, 2, 1, 0, 2, 1, 3, 3, 3]
# Intermolecule:  [1, 3, 0, 0, 2, 2, 3, 1, 1, 2, 3, 3]  Length:  12   [0, 1, 2, -2, 0, 3, 2, 3, 3, 2, 1]  Length:  11
#  After Intermolecule:  [2, 3, 1, 1, 2, 3, 3, 1, 2, -2, 0, 1]   [3, 2, 3, 3, 2, 1, 3, 0, 0, 2, 0]
# On Wall:  [3, 0, 1, 2, 1, 0, 1, 3, 3, 2, 3]
# On Wall:  [2, 1, 0, 3, 3, 2, 1, 3, -1, 1, 3, 2]
# On Wall:  [1, 0, -1, 1, 0, 3, 3, 2, 1, 0, 3]
# Intermolecule:  [3, 0, 1, 2, 1, 0, 1, 3, 3, -1, 3]  Length:  11   [2, 3, 3, 0, 3, 2, 2, 1, 2, 1, 0, 3]  Length:  12
#  After Intermolecule:  [1, 0, 3, 0, 1, 2, 1, 0, 1, 3, 3]   [3, -1, 3, 2, 3, 3, 0, 3, 2, 2, 1, 2]
# On Wall:  [3, 0, 1, 2, 2, 3, 3, 0, 1, 3]
# On Wall:  [0, 1, 2, -2, 0, 3, 2, 3, 3, 2, 1]
# On Wall:  [3, 2, 1, 0, 1, 2, 3, 2, 1, 3]
# On Wall:  [2, 0, 1, 2, 1, 3, 0, 0, 2, 1, 3]
# On Wall:  [2, 0, 0, 3, 1, 2, 1, 0, 3, 3, 2, 1]
# Intermolecule:  [1, 3, 0, 0, 2, 2, 3, 1, 1, 2, 3, 3]  Length:  12   [0, 2, 2, -2, 0, 3, 2, 3, 3, 2, 1]  Length:  11
#  After Intermolecule:  [3, 1, 1, 2, 3, 3, 0, 2, 2, -2, 0, 3]   [2, 3, 3, 2, 1, 1, 3, 0, 0, 2, 2]
# On Wall:  [0, 1, 1, 0, -2, 2, 0, 3, 2, 1]
# Intermolecule:  [0, 2, 1, 3, 2, 1, 1, 0, 3, 3]  Length:  10   [2, 0, 1, 1, 2, 3, 3, 3, 0, 2, 2, 1]  Length:  12
#  After Intermolecule:  [3, 3, 1, 2, 3, 3, 3, 0, 2, 1]   [0, 2, 2, 1, 3, 2, 1, 1, 0, 2, 0, 1]
# On Wall:  [0, 2, 2, -2, 0, 3, 2, 3, 3, 2, 1]
# On Wall:  [1, 2, -1, 1, 2, 2, 2, 3, 1]
# On Wall:  [1, 2, 1, 1, 2, 2, 2, 3, 1]
# On Wall:  [3, 0, 1, 2, 2, 3, 3, 0, -2, 3]
# On Wall:  [3, 0, 1, 2, 2, 2, 3, 0, -2, 3]
# On Wall:  [1, 0, 3, 3, 2, 1, 2, 1, 2, 3, 3]
# On Wall:  [0, 2, 1, 1, 2, 1, 2, 3, 2, 0, 2, 1]
# Intermolecule:  [0, 1, 1, 0, -2, 2, 0, 3, 2, 1]  Length:  10   [3, 2, 1, 0, 1, 2, 3, 2, 1, 1]  Length:  10
#  After Intermolecule:  [0, 3, 2, 1, 0, 1, 2, 0, 1, 1]   [3, 2, 1, 1, 0, -2, 2, 3, 2, 1]
# Intermolecule:  [1, 3, 0, 0, 2, 2, 3, 1, 1, 2, 3, 3]  Length:  12   [0, 2, 1, 3, 2, 1, 1, 0, 3, 3]  Length:  10
#  After Intermolecule:  [1, 2, 3, 3, 1, 0, 1, 3, 0, 0, 2, 2]   [3, 3, 3, 1, 0, 2, 1, 3, 2, 1]
# On Wall:  [2, 0, 1, 1, 2, 3, 3, 3, 0, 2, 2, 1]
# On Wall:  [0, 2, 1, -2, 2, 1, 2, 3, 2, 0, 2, 1]
# On Wall:  [2, 0, 1, 1, 2, 3, 3, 3, 0, 2, 2, 1]
# Intermolecule:  [2, 3, 3, 0, 3, 2, 2, 1, 2, 1, 0, 3]  Length:  12   [1, 3, 0, 0, 2, 2, 3, 1, 1, 2, 3, 3]  Length:  12
#  After Intermolecule:  [2, 1, 2, 1, 0, 3, 0, 0, 2, 2, 2, 3]   [3, 1, 1, 2, 3, 3, 3, 0, 3, 2, 1, 3]
# Intermolecule:  [2, 3, 3, 0, 3, 2, 2, 1, 2, 1, 0, 3]  Length:  12   [0, 2, 1, 3, 2, 1, 1, 0, 3, 3]  Length:  10
#  After Intermolecule:  [0, 3, 3, 3, 2, 3, 3, 0, 3, 2, 2, 1]   [2, 1, 0, 2, 1, 3, 2, 1, 1, 0]
# On Wall:  [0, 2, 1, -2, 2, 1, -1, 3, 2, 0, 2, 1]
# On Wall:  [2, 0, 0, 3, 1, 2, 3, 0, 3, 3, 2, 1]
# On Wall:  [1, 0, 3, 3, 2, 1, 2, 1, 2, 3, 3]
# On Wall:  [0, 2, 2, -2, 0, 3, 2, 3, 3, -1, 1]
# On Wall:  [0, 1, 2, 0, 3, 0, 1, 2, 3, 1]
# Intermolecule:  [1, 2, 0, 3, 2, 2, 3, 3, 3, 2, 2, -2]  Length:  12   [2, 3, 3, 0, 3, 2, 2, 1, 2, 1, 0, 3]  Length:  12
#  After Intermolecule:  [-2, 2, 1, 0, 1, 2, 0, 3, 2, 2, 3, 3]   [3, 3, 2, 2, 2, 3, 3, 0, 3, 2, 2, 1]
# On Wall:  [3, 2, 1, 0, 1, 2, 3, 2, 1, 1]
# On Wall:  [0, 1, 0, 3, 3, 2, 1, 3, -1, 1, 3, 2]
# On Wall:  [0, 3, 3, 2, 1, 3, 3, 3, 0, 1, 2]
# On Wall:  [1, 0, 1, 3, 2, 1, 2, 1, 2, 3, 3]
# On Wall:  [1, 0, 0, 1, 0, 3, 3, 2, 1, 0, 3]
# On Wall:  [0, 3, 3, 2, 1, 3, 3, 1, 0, 1, 2]
# On Wall:  [2, 3, 3, 0, 3, 2, 2, 1, 2, 1, 0, 3]
# On Wall:  [1, 3, 0, 0, 2, 2, 3, 1, 1, 2, 3, 3]
# Intermolecule:  [0, 2, 1, 3, 2, 1, 1, 0, 3, 3]  Length:  10   [0, 2, 2, -2, 2, 1, -1, 3, 2, 0, 2, 1]  Length:  12
#  After Intermolecule:  [0, 3, 3, 2, 1, -1, 0, 2, 1, 3]   [3, 2, 0, 2, 1, 2, 1, 1, 0, 2, 2, -2]
# On Wall:  [0, 1, 0, 3, 3, 2, 1, 3, 0, 1, 3, 2]
# Intermolecule:  [0, 2, 2, -2, 2, 1, -1, 3, 2, 0, 2, 1]  Length:  12   [0, 1, 0, 1, 3, 2, 1, 3, 0, 1, 3, 2]  Length:  12
#  After Intermolecule:  [3, 2, 0, 2, 2, -2, 2, 1, -1, 3, 2, 0]   [2, 1, 0, 1, 0, 1, 3, 2, 1, 3, 0, 1]
# Intermolecule:  [0, 1, 0, 1, 3, 2, 1, 3, 0, 1, 3, 2]  Length:  12   [0, 3, 3, 0, 1, 3, 3, 1, 0, 1, 2]  Length:  11
#  After Intermolecule:  [2, 1, 0, 1, 2, 0, 1, 0, 1, 3, 2, 1]   [3, 0, 1, 3, 0, 3, 3, 0, 1, 3, 3]
# On Wall:  [3, 0, 1, 2, 1, 0, 1, 3, 3, -1, 3]
# On Wall:  [2, 0, 1, 2, 1, 0, 0, 0, 2, 1, 3]
# On Wall:  [1, 2, 1, 1, 2, 2, -1, 3, 1]
# On Wall:  [3, 1, 2, 0, 3, 0, 1, 2, 3, 1]
# On Wall:  [0, 2, 1, 3, 2, 1, 1, 0, 3, 3]
# On Wall:  [3, 2, 1, 0, 1, 2, 3, 2, 1, 1]
# Intermolecule:  [2, 0, 1, 2, 1, 0, 0, 0, 0, 1, 3]  Length:  11   [0, 2, 1, 3, 3, 1, 1, 0, 3, 3]  Length:  10
#  After Intermolecule:  [0, 1, 3, 1, 0, 2, 0, 1, 2, 1, 0]   [3, 3, 0, 0, 0, 2, 1, 3, 3, 1]
# On Wall:  [1, 0, 0, 1, 0, 3, 1, 2, 1, 0, 3]
# On Wall:  [0, 2, 2, -2, 0, 3, 2, 3, 3, 0, 1]
# On Wall:  [0, 1, 0, 1, 3, 2, 1, 3, 0, 1, 3, 2]
# On Wall:  [3, 2, 1, 0, 1, 2, 2, 2, 1, 1]
# Intermolecule:  [1, 2, 1, 1, 2, 3, -1, 3, 1]  Length:  9   [3, 1, 2, 0, 3, 0, 1, 2, 0, 1]  Length:  10
#  After Intermolecule:  [-1, 3, 1, 2, 0, 3, 0, 1, 2]   [1, 2, 0, 1, 1, 1, 2, 3, 3, 1]
# On Wall:  [1, 2, 0, 3, 2, 2, 3, 3, 3, 2, 2, -2]
# On Wall:  [0, 2, 1, 3, 3, 1, 1, 0, 3, 3]
# On Wall:  [2, 3, 1, 0, 3, 2, 2, 1, 2, 1, 0, 3]
# On Wall:  [2, 3, 1, 0, 3, 2, 2, -2, 2, 1, 0, 3]
# Intermolecule:  [1, 2, 0, 3, 2, 2, 3, 3, 3, 2, 2, -2]  Length:  12   [2, 0, 0, 3, 1, 2, 3, 0, 3, 3, 2, 1]  Length:  12
#  After Intermolecule:  [-2, 0, 3, 1, 2, 3, 0, 3, 3, 2, 1, 2]   [1, 0, 3, 2, 2, 3, 3, 3, 2, 2, 2, 0]
# On Wall:  [1, 2, 0, 3, 2, 2, 3, 3, 3, 2, 2, -2]
# On Wall:  [1, 0, 0, 1, 0, 3, 2, 2, 1, 0, 3]
# On Wall:  [1, 2, 1, 1, 2, 3, -1, 3, 1]
# On Wall:  [1, 3, 0, 0, 2, 2, 3, 1, 1, 2, 2, 3]
# On Wall:  [0, 2, 2, -2, 2, 1, -1, 3, 2, 0, 2, 1]
# Intermolecule:  [1, 0, -2, 3, 2, 1, 2, 1, 2, 3, 3]  Length:  11   [3, 0, 1, 2, -2, 0, 1, 3, 3, -1, 3]  Length:  11
#  After Intermolecule:  [3, 3, 1, 3, 3, 1, 0, -2, 3, 2, 1]   [-1, 3, 2, 1, 2, 3, 0, 1, 2, -2, 0]
# On Wall:  [1, 2, 1, 1, 2, 3, -1, 3, 1]
# On Wall:  [3, 0, 1, 2, 2, 2, 3, 0, -1, 3]
# On Wall:  [2, 0, 1, 0, 3, 2, 2, -2, 2, 1, 0, 3]
# Intermolecule:  [2, 0, 0, 3, 1, 2, 3, 0, 3, 3, 2, 1]  Length:  12   [2, 2, 0, 3, 2, 2, 3, 3, 3, 2, 2, -2]  Length:  12
#  After Intermolecule:  [2, 1, 2, 2, 3, 3, 3, 2, 2, 0, 0, 3]   [2, -2, 1, 2, 3, 0, 3, 3, 2, 2, 0, 3]
# On Wall:  [1, 0, 1, 2, 2, 2, 3, 0, -1, 3]
# On Wall:  [3, 2, 1, 1, 2, 3, -1, 3, 1]
# On Wall:  [1, 0, 1, 2, 2, 2, 0, 0, -1, 3]
# On Wall:  [0, 1, 1, 0, -2, 2, 0, 3, 2, 1]
# On Wall:  [1, 3, 0, 1, 2, 2, 3, 1, 1, 2, 2, 3]
# On Wall:  [0, 3, 1, 0, -2, 2, 0, 3, 2, 1]
# On Wall:  [2, 0, 1, 1, 2, 3, 3, 3, 0, 2, 2, 1]
# On Wall:  [1, 0, 0, 1, 0, 3, 2, 2, 1, 0, 3]
# On Wall:  [2, 2, 0, 3, 2, 2, 3, 3, 3, 2, 2, -2]
# Intermolecule:  [2, 0, 1, 2, 1, 0, 0, 0, 0, 1, 3]  Length:  11   [2, 0, 1, 1, 2, 3, 3, 3, 3, 2, 2, 1]  Length:  12
#  After Intermolecule:  [3, 3, 3, 2, 2, 2, 0, 1, 2, 1, 0]   [1, 0, 0, 0, 1, 3, 2, 0, 1, 1, 2, 3]
# Intermolecule:  [2, 0, 1, 0, 3, 2, -1, -2, 2, 1, 0, 3]  Length:  12   [1, 0, -2, 3, 2, 1, 2, 1, 2, 3, 3]  Length:  11
#  After Intermolecule:  [3, 2, 1, 2, 3, 3, 2, 0, 1, 0, 3, 2]   [-1, -2, 2, 1, 0, 1, 0, -2, 3, 2, 1]
# On Wall:  [3, 2, 1, 0, 1, 2, 2, 2, 1, 1]
# On Wall:  [1, 0, 3, 1, 0, 3, 2, 2, 1, 0, 3]
# On Wall:  [0, 2, 2, -2, 2, 1, -1, 3, 3, 0, 2, 1]
# On Wall:  [3, 2, 1, 1, 2, 1, -1, 3, 1]
# On Wall:  [0, 1, 0, 2, 1, 0, 2, 1, 3, 3, 3]
# On Wall:  [0, 2, 2, -2, 0, 3, 2, 3, 3, 0, 1]
# Intermolecule:  [1, 0, -2, 3, 2, 1, 2, 1, 2, 3, 3]  Length:  11   [0, 1, 2, 1, 3, 2, 1, 3, 0, 1, 3, 2]  Length:  12
#  After Intermolecule:  [1, 3, 2, 1, 3, 0, 1, 3, 1, 0, -2]   [2, 3, 2, 1, 2, 1, 2, 3, 3, 0, 1, 2]
# On Wall:  [0, 2, 3, 3, 3, 1, 1, 0, 3, 3]
# On Wall:  [2, 0, 1, 2, 1, 0, 0, 0, 0, 1, 3]
# On Wall:  [0, 3, 3, 0, 1, 3, 3, 1, 0, 1, 2]
# On Wall:  [2, 0, 1, 3, 1, 0, 0, 0, 0, 1, 3]
# On Wall:  [3, 2, 1, 0, 1, 3, 2, 2, 1, 1]
# Intermolecule:  [0, 1, 2, 1, 3, 2, 1, 3, 0, 1, 3, 2]  Length:  12   [0, 1, 0, 2, 1, 3, 2, 1, 3, 3, 3]  Length:  11
#  After Intermolecule:  [1, 3, 2, 0, 1, 0, 2, 1, 3, 2, 1, 3]   [3, 3, 0, 1, 2, 1, 3, 2, 1, 3, 0]
# On Wall:  [1, 0, -2, 3, 2, 1, 2, 1, 2, 3, 3]
# On Wall:  [0, 1, 0, 2, 1, 3, 2, 1, 3, 3, 3]
# On Wall:  [2, 2, 2, -2, 0, 3, 2, 3, 3, 0, 1]
# On Wall:  [2, 0, 1, 3, -2, 0, 0, 0, 0, 1, 3]
# On Wall:  [1, 0, -2, 3, 2, 1, 2, 2, 2, 3, 3]
# Systhesis
# Systhesis
# On Wall:  [3, 1, 2, 0, 3, 0, 1, 2, 0, 1]
# On Wall:  [3, 1, 3, 0, 3, 0, 1, 2, 0, 1]
# On Wall:  [3, 0, 1, 1, 2, 1, -1, 3, 1]
# Systhesis
# Intermolecule:  [0, 3, 3, 0, 1, 0, 3, 1, 0, 1, 2]  Length:  11   [1, 0, 1, 3, 2, 1, 2, 2, 2, 3, 3]  Length:  11
#  After Intermolecule:  [2, 1, 2, 2, 2, 3, 3, 0, 3, 3, 0]   [1, 0, 3, 1, 0, 1, 2, 1, 0, 1, 3]
# On Wall:  [1, 0, 3, 1, 0, 3, 2, 2, 1, 0, 3]
# Systhesis
# On Wall:  [2, 0, 1, 1, 2, 3, 3, 3, 3, 2, 2, 1]
# Intermolecule:  [3, 0, 1, 1, 2, 1, -1, 3, 3]  Length:  9   [1, 0, 1, 3, 2, 1, 2, 2, 2, 3, 3]  Length:  11
#  After Intermolecule:  [2, 2, 2, 3, 0, 1, 1, 2, 1]   [3, 3, -1, 3, 3, 1, 0, 1, 3, 2, 1]
# On Wall:  [3, 2, 3, 0, 3, 0, 1, 2, 0, 1]
# On Wall:  [0, 3, 3, 0, 1, 0, 3, 1, 0, 1, 2]
# On Wall:  [2, 0, 1, 1, 2, 3, 3, 3, 1, 2, 2, 1]
# On Wall:  [2, 0, 1, 3, -2, 0, 0, 0, 0, 1, 3]
# On Wall:  [3, 2, 1, 0, 1, 3, 2, 2, 1, 1]
# On Wall:  [1, 0, 1, 3, 2, 1, 2, 2, 2, 3, 3]
# On Wall:  [2, 0, 1, 3, 0, 0, 0, 0, 0, 1, 3]
# On Wall:  [0, 2, 0, 2, 1, 3, 2, 1, 3, 3, 3]
# On Wall:  [3, 2, -2, 0, 1, 3, 2, 2, 1, 1]
# On Wall:  [0, 3, 3, 0, 1, 0, 3, 1, 0, 1, 2]
# On Wall:  [1, 0, 3, 1, 0, 3, 2, 2, 1, 2, 3]
# On Wall:  [1, 0, 1, 2, 2, 2, 0, 0, -1, 2]
# On Wall:  [0, 1, 2, 1, 3, 2, 1, 3, 0, 1, 3, 2]
# On Wall:  [0, 3, 2, -2, 2, 1, -1, 3, 3, 0, 2, 1]
# Systhesis
# On Wall:  [1, 3, 0, 1, 2, 2, 3, 2, 1, 2, 2, 3]
# Intermolecule:  [1, 2, 1, 3, 2, 1, 2, 2, 2, 3, 3]  Length:  11   [2, 0, 0, 3, 1, 2, 3, 0, 3, 3, 2, 1]  Length:  12
#  After Intermolecule:  [3, 3, 0, 3, 1, 2, 3, 0, 3, 1, 2]   [3, 2, 1, 1, 3, 2, 1, 2, 2, 2, 2, 0]
# On Wall:  [0, 3, 0, 0, 1, 0, 3, 1, 0, 1, 2]
# On Wall:  [3, 2, 1, 0, 1, 3, 2, 2, 1, 1]
# On Wall:  [2, 0, 1, 1, 2, 3, 3, 3, -2, 2, 2, 1]
# On Wall:  [2, 0, 1, 1, 2, 3, 3, 3, -2, 2, 2, 1]
# On Wall:  [3, 2, 1, 0, 1, 1, 2, 2, 1, 1]
# On Wall:  [2, 2, 2, -2, 0, 3, 2, 3, 0, 0, 1]
# On Wall:  [0, 3, 2, -2, 2, 1, -1, 3, 3, 0, 2, 1]
# On Wall:  [0, 1, -1, 1, 3, 2, 1, 3, 0, 1, 3, 2]
# On Wall:  [1, 2, 1, 3, 2, 1, 2, 2, 2, 3, 3]
# Systhesis
# On Wall:  [0, 2, 0, 2, 1, 3, 2, 1, 3, 3, 3]
# On Wall:  [1, 0, 1, 2, 2, 2, 0, 3, -1, 2]
# On Wall:  [0, 3, 0, 0, 1, 0, 3, 1, 0, 1, 2]
# On Wall:  [2, 0, 1, 0, 3, 2, -1, -2, 2, 1, 0, 3]
# On Wall:  [3, 2, -2, 0, 1, 1, 2, 2, 1, 1]
# Intermolecule:  [1, 2, 1, 3, 2, 2, 2, 2, 2, 3, 3]  Length:  11   [2, 0, 0, 3, 1, 2, 3, 0, 3, 3, 2, 1]  Length:  12
#  After Intermolecule:  [2, 3, 3, 2, 0, 0, 3, 1, 2, 3, 0]   [3, 3, 2, 1, 1, 2, 1, 3, 2, 2, 2, 2]
# On Wall:  [2, 2, 2, -2, 0, 3, 2, 3, 0, 0, 3]
# On Wall:  [1, 0, 1, 2, 2, 2, 2, 3, -1, 2]
# On Wall:  [0, 3, 3, -2, 2, 1, -1, 3, 3, 0, 2, 1]
# On Wall:  [0, 3, 3, -2, 2, 1, -1, 3, 3, 0, 2, 1]
# Systhesis
# Systhesis
# On Wall:  [0, 3, 3, -2, 0, 1, -1, 3, 3, 0, 2, 1]
# On Wall:  [0, 1, -1, 1, 3, 2, 1, 3, 0, 1, 3, 2]
# On Wall:  [3, 0, 1, 2, -2, 0, 1, 3, 3, -1, 3]
# On Wall:  [0, 3, 0, 0, 1, 0, 2, 1, 0, 1, 2]
# On Wall:  [0, 2, 3, 3, 1, 1, 1, 0, 3, 3]
# On Wall:  [0, 3, 0, 0, 1, 0, 2, 1, 1, 1, 2]
# On Wall:  [3, 0, 1, 1, 2, 1, -1, 3, 3]
# On Wall:  [1, 0, 3, 1, 0, 3, 2, 2, -2, 2, 3]
# Systhesis
# Systhesis
# On Wall:  [1, 0, 3, 1, 2, 3, 2, 2, -2, 2, 3]
# On Wall:  [-1, 2, 2, -2, 0, 3, 2, 3, 0, 0, 3]
# On Wall:  [2, 0, 0, 3, 1, 2, 3, 0, 3, 3, 2, 1]
# On Wall:  [1, 3, 0, 1, 2, 2, 3, 2, 1, 2, 2, 3]
# On Wall:  [0, 0, 1, 1, 2, 1, -1, 3, 3]
# Systhesis
# On Wall:  [2, 2, 0, 3, 2, 2, 3, 3, 3, 2, 2, -2]
# On Wall:  [1, 0, 3, -2, 2, 3, 2, 2, -2, 2, 3]
# Systhesis
# Systhesis
# On Wall:  [1, 0, 3, -2, 2, 3, 2, 2, -2, 3, 3]
# Systhesis
# Systhesis
# On Wall:  [0, 3, 1, 0, -2, 2, 0, 2, 2, 1]
# On Wall:  [0, 3, 3, -2, 0, 2, -1, 3, 3, 0, 2, 1]
# On Wall:  [1, 3, 0, 1, 2, 2, 3, 2, 1, 2, 2, 3]
# On Wall:  [2, 2, 0, 0, 2, 2, 3, 3, 3, 2, 2, -2]
# On Wall:  [2, 0, 1, 0, 3, 2, -1, -2, 2, 1, 3, 3]
# On Wall:  [1, 3, 0, 1, 2, 2, 3, 2, 1, 2, 2, 3]
# On Wall:  [1, 3, 0, 1, 2, 2, 3, 2, 1, 0, 2, 3]
# Systhesis
# On Wall:  [2, 2, 0, 0, -1, 2, 3, 3, 3, 2, 2, -2]
# On Wall:  [0, 3, 0, 0, 1, 0, 2, 2, 1, 1, 2]
# Systhesis
# On Wall:  [2, 2, 2, -2, 0, 3, 2, 3, 0, 0, 3]
# On Wall:  [3, 0, 1, 2, -2, 0, 1, 3, 0, -1, 3]
# Systhesis
# On Wall:  [0, 3, 3, -2, 0, 2, -1, 3, 2, 0, 2, 1]
# On Wall:  [0, 3, 3, -2, 0, 2, -1, 3, 2, 0, 2, 1]
# On Wall:  [2, 0, 1, 0, 3, 2, -1, 1, 2, 1, 3, 3]
# On Wall:  [0, 2, 0, 2, 1, 3, 2, 3, 3, 3, 3]
# Systhesis
# On Wall:  [2, 0, 1, 0, 3, 2, 2, 1, 2, 1, 3, 3]
# Systhesis
# On Wall:  [1, 2, 1, 3, 2, 2, 2, 2, 2, 3, 3]
# Systhesis
# On Wall:  [2, 0, 1, 1, 2, 3, 3, 3, -2, 2, 2, 1]
# Systhesis
# Systhesis
# Systhesis
# Systhesis
# On Wall:  [3, 2, 3, 0, 3, 0, 1, 2, 0, 1]
# Systhesis
# On Wall:  [3, 1, 1, 2, -2, 0, 1, 3, 0, -1, 3]
# On Wall:  [3, 1, 1, 2, -2, 0, 1, 3, 0, -1, 3]
# On Wall:  [1, 0, 3, -1, 2, 3, 2, 2, -2, 3, 3]
# Systhesis
# On Wall:  [2, 2, 2, -2, 0, 3, 0, 3, 0, 0, 3]
# Systhesis
# On Wall:  [2, 1, 1, 2, -2, 0, 1, 3, 0, -1, 3]
# Systhesis
# On Wall:  [-2, 3, 0, 1, 2, 2, 3, 2, 1, 0, 2, 3]
# On Wall:  [0, 0, 1, 1, 3, 1, -1, 3, 3]
# On Wall:  [0, 3, 3, -2, 0, 2, -1, 3, 2, 0, 2, 1]
# On Wall:  [-2, 3, 0, 1, -1, 2, 3, 2, 1, 0, 2, 3]
# On Wall:  [2, 0, 1, 1, 2, 3, 3, 3, -2, 2, 2, 2]
# On Wall:  [2, 1, 1, 2, -2, 3, 1, 3, 0, -1, 3]
# On Wall:  [-2, 3, 0, 1, -1, 2, 2, 2, 1, 0, 2, 3]
# On Wall:  [2, 1, 1, 2, -2, 3, 1, 0, 0, -1, 3]
# On Wall:  [0, 2, 0, 2, 1, 3, 2, 1, 3, 3, 3]
# On Wall:  [1, 0, 3, -1, 2, 3, 2, -1, -2, 3, 3]
# On Wall:  [1, 2, 1, 3, 3, 2, 2, 2, 2, 3, 3]
# On Wall:  [1, 2, 1, 3, 3, 2, -1, 2, 2, 3, 3]
# On Wall:  [2, 0, 1, 0, 3, 2, 2, 1, 2, 1, 3, 3]
# On Wall:  [3, 2, 3, 0, 3, 0, 1, 2, 0, 1]
# On Wall:  [0, 3, 3, 0, 1, 0, 2, 2, 1, 1, 2]
# On Wall:  [2, 1, 1, 2, -2, 3, 1, 0, 0, -1, 3]
# Decomposition
# Systhesis
# On Wall:  [2, 0, 1, 1, 2, 3, 3, 2, -2, 2, 2, 2]
# On Wall:  [1, 2, 1, 3, 3, 2, -1, 2, 2, 3, 3]
# On Wall:  [0, 2, 0, -1, 1, 3, 2, 1, 3, 3, 3]
# On Wall:  [0, 1, -1, 1, 3, 2, 1, 3, 0, -2, 3, 2]
# On Wall:  [1, 2, 1, 3, 3, 2, 2, 2, 2, 3, 3]
# On Wall:  [0, 3, 1, 0, -2, -1, 0, 2, 2, 1]
# Systhesis
# On Wall:  [0, 3, 1, 0, 1, -1, 0, 2, 2, 1]
# On Wall:  [3, 0, 1, 0, 3, 2, 2, 1, 2, 1, 3, 3]
# On Wall:  [0, 3, 1, 0, 1, -1, 0, 2, 3, 1]
# Systhesis
# Intermolecule:  [0, 3, 3, -2, 0, 2, -1, 3, 2, 0, 2, 1]  Length:  12   [2, 0, 1, 3, 0, 0, 2, 0, 0, 1, 3]  Length:  11
#  After Intermolecule:  [2, -1, 3, 2, 0, 2, 1, 1, 3, 0, 0, 3]   [0, 2, 0, 0, 1, 3, 3, -2, 0, 2, 0]
# Systhesis
# On Wall:  [2, 2, 2, -2, 0, 3, 0, 3, 0, 0, 3]
# On Wall:  [1, 2, 1, 3, 2, 2, 2, 2, 2, 3, 3]
# On Wall:  [3, 2, 3, 0, 3, 0, 1, 2, 0, 2]
# Systhesis
# On Wall:  [0, 0, 1, 1, 3, -2, -1, 3, 3]
# On Wall:  [0, 2, 3, 1, 1, 1, 1, 0, 3, 3]
# On Wall:  [2, 0, 1, 1, 2, 3, 3, 2, -1, 2, 2, 2]
# On Wall:  [2, 0, 0, 3, 1, 2, 3, 0, 3, 3, 2, 1]
# On Wall:  [0, 3, 3, 0, 1, 0, 2, 2, 1, 1, 2]
# On Wall:  [0, 1, -1, 1, 3, 2, 3, 3, 0, -2, 3, 2]
# On Wall:  [3, 0, 1, 0, 3, 2, 3, 1, 2, 1, 3, 3]
# On Wall:  [0, 0, 1, 1, 3, -2, -1, 3, 1]
# On Wall:  [3, 2, -2, 0, 1, 1, 2, 2, 1, 1]
# Systhesis
# On Wall:  [2, 0, 1, 1, 2, 3, 3, 2, -1, 2, 2, 2]
# Systhesis
# On Wall:  [0, 0, 1, 1, 3, 0, -1, 3, 1]
# On Wall:  [1, 0, 3, -1, 2, 3, 2, -1, -2, 0, 3]
# Decomposition
# On Wall:  [2, 0, 1, 3, 0, 0, 2, 0, 0, 1, 3]
# On Wall:  [1, 2, -2, 3, 2, 2, 2, 2, 2, 3, 3]
# On Wall:  [0, 1, -1, 1, 3, 2, 3, 3, 0, -2, 3, 3]
# Decomposition
# On Wall:  [2, 0, 1, 1, 2, 3, 3, 2, -1, 2, 2, 2]
# Systhesis
# On Wall:  [1, 3, -2, 3, 2, 2, 2, 2, 2, 3, 3]
# On Wall:  [1, 0, 1, 2, 2, 2, 2, 3, -1, 2]
# On Wall:  [1, 3, 1, 3, 2, 2, 2, 2, 2, 3, 3]
# Systhesis
# Systhesis
# On Wall:  [0, 3, 3, 0, 1, 0, 2, -1, 1, 1, 2]
# On Wall:  [0, 3, 2, 0, 1, 0, 2, -1, 1, 1, 2]
# Systhesis
# On Wall:  [0, 1, -1, 1, 3, 2, 3, 3, 0, -2, 3, 3]
# Systhesis
# On Wall:  [0, 3, 2, 0, 1, 0, 2, -1, 1, 1, 2]
# On Wall:  [-2, 3, 0, 1, -1, 2, 2, 2, 1, 2, 2, 3]
# Intermolecule:  [3, 1, 0, 0, 1, 1, 3, 2, -1]  Length:  9   [-2, 3, 0, 1, 0, 2, 2, 2, 1, 2, 2, 3]  Length:  12
#  After Intermolecule:  [2, -1, 0, 1, 0, 2, 2, 3, 1]   [2, 1, 2, 2, 3, 0, 0, 1, 1, 3, -2, 3]
# On Wall:  [1, 3, 1, 3, 2, 2, 2, 2, 2, 3, 3]
# Decomposition
# On Wall:  [1, 0, 1, 3, 2, 2, 2, 2, 2, 3, 3]
# Decomposition
# On Wall:  [0, 3, 1, 0, 1, -1, 0, 2, 3, 1]
# On Wall:  [3, 2, 0, 2, 1, 0, 3, 3, -2, 0, 2, -1]
# Systhesis
# On Wall:  [3, 0, 1, 0, 3, 2, 3, -2, 2, 1, 3, 3]
# On Wall:  [3, 2, 0, 2, 1, 0, 3, 0, -2, 0, 2, -1]
# On Wall:  [0, 2, 3, 1, 3, 1, 1, 0, 3, 3]
# On Wall:  [2, 0, 1, 1, 2, 3, 3, 2, -1, 2, 3, 2]
# On Wall:  [0, 3, 1, 0, -2, -1, 0, 2, 3, 1]
# On Wall:  [0, 2, 3, 1, 3, 3, 1, 0, 3, 3]
# On Wall:  [1, 0, 1, 2, 2, 2, -1, 3, -1, 2]
# Decomposition
# Decomposition
# Intermolecule:  [-1, 3, 1, 0, 0, 1, 1, 3, 2]  Length:  9   [0, 1, 1, 1, 3, 2, 3, 3, 0, -2, 3, 3]  Length:  12
#  After Intermolecule:  [1, 1, 3, 2, 1, 1, 1, 3, -1]   [2, 3, 3, 0, -2, 3, 3, 3, 1, 0, 0, 0]
# Intermolecule:  [0, 2, -1, 3, 2, 0, 2, 1, 0, 3, 3, -2]  Length:  12   [1, 0, 3, -1, 2, 3, -1, -1, -2, 0, 3]  Length:  11
#  After Intermolecule:  [3, 2, 0, 2, 1, 0, 3, 3, -2, 0, 3, 0]   [-1, 2, 3, -1, -1, -2, 0, 3, 2, -1, 1]
# On Wall:  [2, 1, 1, 2, -2, 3, 1, 0, 0, -1, 3]
# Decomposition
# Decomposition
# On Wall:  [1, 2, -2, 0, 1, 1, 2, 2, 1, 1]
# On Wall:  [-2, 3, 0, 1, 0, 2, 2, 2, 1, 2, 2, 3]
# On Wall:  [1, 0, 3, -1, 2, 3, -1, -1, -2, 0, 3]
# Systhesis
# On Wall:  [3, 2, 2, -2, 0, 3, 0, 3, 0, 0, 3]
# Decomposition
# Systhesis
# On Wall:  [3, 2, 2, -2, 0, 3, 0, 3, 0, 2, 3]
# Systhesis
# On Wall:  [2, 0, 0, 3, 1, 2, 3, 0, 3, 3, 2, 1]
# On Wall:  [3, 3, -2, 0, 2, -1, 3, 2, 0, 2, 1, 0]
# On Wall:  [3, 2, 0, 0, -1, 2, 3, 3, 3, 2, 2, -2]
# On Wall:  [3, 2, 0, 0, -1, 2, 3, 3, 3, 2, 2, -2]
# On Wall:  [2, 2, 0, 2, 1, 0, 3, 0, -2, 0, 2, -1]
# On Wall:  [3, 2, 0, 0, -1, 2, 3, 3, 3, 3, 2, -2]
# Decomposition
# Systhesis
# On Wall:  [3, 3, -2, 0, 2, -1, 3, 2, 0, 2, 1, 0]
# On Wall:  [-2, 3, 0, 2, 0, 2, 2, 2, 1, 2, 2, 3]
# Systhesis
# Decomposition
# Systhesis
# Decomposition
# On Wall:  [0, 3, 2, 0, 1, 0, 2, -1, -2, 1, 2]
# On Wall:  [2, 0, 3, 3, 1, 2, 3, 0, 3, 3, 2, 1]
# On Wall:  [2, 0, 3, 3, 1, 2, 3, 0, 3, 3, 0, 1]
# On Wall:  [2, 0, 1, 1, 2, 3, 2, 2, -1, 2, 3, 2]
# On Wall:  [0, 0, 1, 1, 3, 2, -1, 3, 1]
# Decomposition
# Systhesis
# On Wall:  [3, 0, 1, 0, 3, 2, 3, -2, 2, -2, 3, 3]
# On Wall:  [3, 3, -2, 0, 2, -1, 3, 2, 3, 2, 1, 0]
# On Wall:  [0, 2, 0, -1, 1, 3, 2, 1, 3, 3, 3]
# On Wall:  [3, 3, -2, 0, 2, -1, 3, 2, 2, 2, 1, 0]
# On Wall:  [2, 0, 1, 3, 0, 0, 2, 0, 0, -2, 3]
# On Wall:  [2, 2, 2, 2, 0, 3, 3, 1, 0, 1, 3]
# Decomposition
# Decomposition
# Decomposition
# On Wall:  [2, 1, 1, 2, -2, 3, 1, 3, 0, -1, 3]
# Decomposition
# Systhesis
# Decomposition
# On Wall:  [2, -1, 3, 1, 0, 0, 1, 1, 3]
# On Wall:  [0, 1, 1, 1, 3, 2, 3, 3, 0, -2, 3, 3]
# On Wall:  [1, 2, -2, 0, 1, 1, 2, 2, 1, 1]
# On Wall:  [3, 2, 3, 0, 3, 0, 1, 2, 0, 2]
# On Wall:  [2, 1, 1, 2, -2, 3, 1, 3, 2, -1, 3]
# On Wall:  [3, 0, 1, 0, 3, 2, 3, -2, 3, -2, 3, 3]
# Decomposition
# Decomposition
# On Wall:  [3, -1, 0, 0, -1, 2, 3, 3, 3, 3, 2, -2]
# On Wall:  [2, -1, 3, 1, 0, 0, 1, 1, 2]
# On Wall:  [1, 3, 2, 2, 2, 2, 0, 3, 3, 1, 0]
# On Wall:  [3, 2, 2, -2, 0, 3, 0, 3, 0, 2, 3]
# On Wall:  [2, 2, 2, 2, 0, 3, 3, 1, 0, 1, 3]
# Systhesis
# On Wall:  [-2, 3, 0, 2, 0, 2, 0, 2, 1, 2, 2, 3]
# Systhesis
# Decomposition
# On Wall:  [3, 3, -2, 0, 2, 1, 3, 2, 3, 2, 1, 0]
# Decomposition
# Decomposition
# Decomposition
# On Wall:  [2, 2, 2, 2, 0, 3, 3, 1, 0, 1, 3]
# On Wall:  [3, -2, 0, 2, -1, 3, 2, 0, 2, 1, 0, 3]
# Systhesis
# On Wall:  [3, 3, -2, 0, 2, -1, 3, 2, 2, 2, 1, 3]
# Systhesis
# On Wall:  [0, 3, 1, 0, -2, -1, 0, 2, 3, 1]
# On Wall:  [0, 2, 0, -1, 1, 3, 2, 1, 2, 3, 3]
# Intermolecule:  [3, -1, -1, -1, 0, 3, 1, 0, 3, -1, 2]  Length:  11   [1, 0, 0, 1, 1, 3, 2, -1, 3]  Length:  9
#  After Intermolecule:  [3, 1, 0, 3, -1, 2, 0, 0, 1, 1, 3]   [3, 2, -1, 3, -1, -1, -1, 0, 1]
# On Wall:  [2, -1, 3, 1, 0, 0, 1, 1, 2]
# Intermolecule:  [3, -1, 0, 0, -1, 2, 3, 3, 3, 3, 2, -2]  Length:  12   [1, 3, 2, -1, 3, 1, 0, 0, 1]  Length:  9
#  After Intermolecule:  [3, 3, 3, 2, -2, 3, 1, 0, 3, -1, 0, 0]   [0, 1, -1, 2, 3, 1, 3, 2, -1]
# Decomposition
# On Wall:  [-2, 0, 2, -1, 3, 2, 0, 2, 1, 0, 3, 3]
# On Wall:  [0, 1, 1, 1, 3, 0, 3, 3, 0, -2, 3, 3]
# On Wall:  [3, -1, 0, 0, -1, 2, 3, 3, 3, 3, 2, -2]
# On Wall:  [1, 3, 2, 2, 2, 2, 0, 3, 3, 1, 3]
# On Wall:  [-2, 3, 0, 2, 0, 2, 0, 0, 1, 2, 2, 3]
# On Wall:  [0, 3, 3, -2, 0, 2, -1, 3, 2, 0, 2, 1]
# Systhesis
# On Wall:  [1, 0, 1, 2, 2, 2, -1, 3, 1, 2]
# On Wall:  [2, 2, 2, 2, 0, 3, 3, 1, 0, 1, 3]
# On Wall:  [3, 2, -2, 0, 1, 1, 2, 2, 1, 1]
# Systhesis
# On Wall:  [2, 0, 2, 1, 0, 3, 3, -2, 0, 2, -1, 3]
# On Wall:  [2, 2, 0, 2, 1, 0, 3, 0, -2, 0, 2, -1]
# On Wall:  [2, 0, 3, 3, 1, 2, 3, 0, 3, 3, 0, 3]
# Systhesis
# On Wall:  [3, -2, 0, 2, -1, 3, 2, 0, 2, 1, 0, 3]
# On Wall:  [2, 3, -2, 0, 2, 1, 3, 2, 3, 2, 1, 0]
# Decomposition
# On Wall:  [3, 3, -2, 0, 2, -1, 3, 2, 0, 2, 1, 0]
# On Wall:  [1, 3, 2, 2, 2, 2, 0, 3, 3, 1, 1]
# On Wall:  [0, -2, 0, 2, -1, 3, 2, 0, 2, 1, 0, 3]
# On Wall:  [-2, 3, 0, 2, 0, 2, 0, 0, 1, 2, 2, 1]
# Intermolecule:  [3, 2, 2, 2, 2, 0, 3, 3, 1, 0, 1]  Length:  11   [3, 3, 1, 0, 1, 3, 2, 2, 2, 2, 0]  Length:  11
#  After Intermolecule:  [0, 1, 2, 2, 3, 2, 2, 2, 2, 0, 3]   [2, 0, 3, 1, 3, 3, 1, 0, 1, 3, 2]
# On Wall:  [2, 2, 0, 2, 1, 0, 3, 0, -2, 0, 2, -1]
# Decomposition
# On Wall:  [2, -1, 3, 2, 0, 2, 1, 0, 3, 3, -2, 0]
# Decomposition
# On Wall:  [3, 2, -2, 0, 1, 1, 2, 2, 1, 1]
# Systhesis
# On Wall:  [1, 3, 2, -1, 3, 1, 0, 0, 1]
# Decomposition
# On Wall:  [2, 2, 0, 2, 1, 0, 3, 0, -2, 0, 2, -1]
# On Wall:  [-2, 0, 2, -1, 3, 2, 0, 2, 1, 0, 3, 3]
# Decomposition
# Decomposition
# On Wall:  [3, -2, 0, 2, -1, 3, 2, 0, 2, 1, 0, 3]
# On Wall:  [2, 2, 2, 0, 3, 3, 1, 0, 1, 3, 2]
# On Wall:  [3, 3, -2, 0, 2, -1, 3, 2, 0, 2, 1, 0]
# On Wall:  [2, 0, 1, 1, 2, 3, 2, 2, -1, 2, 3, 2]
# Decomposition
# On Wall:  [3, 3, -2, 0, 2, -1, 2, 2, 2, 2, 1, 3]
# On Wall:  [2, 2, 0, 2, 0, 3, 3, 1, 0, 1, 3]
# On Wall:  [0, 2, 0, -1, 1, 3, 2, 1, 2, 3, 3]
# On Wall:  [0, 2, -1, 3, 2, 0, 2, 1, 0, 3, 3, -2]
# On Wall:  [2, -2, 0, 2, -1, 3, 2, 0, 2, 1, 0, 3]
# On Wall:  [3, 3, 1, 0, 1, 3, 2, 2, 2, 2, 0]
# On Wall:  [2, 2, 2, 0, 3, 3, 1, 0, -2, 3, 2]
# On Wall:  [2, 2, 0, 2, 1, 0, 3, 0, -2, 0, 2, -1]
# On Wall:  [2, 1, 1, 0, -2, 3, 1, 3, 2, -1, 3]
# Decomposition
# Decomposition
# On Wall:  [0, 3, -2, 0, 2, -1, 2, 2, 2, 2, 1, 3]
# On Wall:  [2, 2, 0, 2, 0, 2, 3, 1, 0, 1, 3]
# On Wall:  [0, 2, 3, 1, 3, 3, 1, 0, 3, 3]
# On Wall:  [0, 3, -1, 0, 1, 0, 2, -1, -2, 1, 2]
# On Wall:  [-1, -1, -1, 0, 3, 1, 0, 3, -1, 2, 3]
# Systhesis
# On Wall:  [3, -1, 0, 1, 0, 2, -1, -2, 1, 2, 0]
# Systhesis
# Systhesis
# Systhesis
# Intermolecule:  [-2, 1, 2, -1, 3, 2, 0, 2, 1, 0, 3, 3]  Length:  12   [2, 0, 3, 3, 1, 0, 1, 3, 2, 2, 2]  Length:  11
#  After Intermolecule:  [2, 1, 0, 3, 3, 0, 1, -2, 1, 2, -1, 3]   [3, 2, 2, 2, 2, 0, 2, 0, 3, 3, 1]
# Systhesis
# Systhesis
# Systhesis
# On Wall:  [0, 1, 1, 1, 3, 0, 3, 3, 0, -1, 3, 3]
# On Wall:  [0, 3, -1, 0, 1, 0, 2, -1, -2, 1, 2]
# On Wall:  [0, 0, 1, 1, 3, 2, 1, 3, 1]
# On Wall:  [2, 0, 3, 3, 2, 2, 3, 0, 3, 3, 0, 3]
# On Wall:  [0, -2, 0, 3, -1, 3, 2, 0, 2, 1, 0, 3]
# On Wall:  [1, 1, 3, 2, -1, 3, 1, 0, 0]
# On Wall:  [1, 0, 3, 3, -2, 0, 2, -1, 3, 2, 0, 2]
# On Wall:  [3, 3, -2, 0, 2, -1, 0, 2, 0, 2, 1, 0]
# On Wall:  [3, 2, 2, 2, 2, 0, 3, 3, 1, 0, 1]
# On Wall:  [3, -1, 3, 0, 3, 0, 1, 2, 0, 2]
# On Wall:  [0, 0, 1, 1, 3, 2, 1, 2, 1]
# On Wall:  [3, 3, -2, 0, 1, 3, 2, 2, 2, 2, 0]
# On Wall:  [2, -1, 0, 2, -1, 3, 2, 0, 2, 1, 0, 3]
# On Wall:  [2, 1, 1, 0, -2, 3, 1, 3, 2, 2, 3]
# On Wall:  [0, 3, -2, 0, 2, -1, 2, 2, 0, 2, 1, 3]
# On Wall:  [2, 3, -2, 0, 2, 3, 3, 2, 3, 2, 1, 0]
# On Wall:  [2, 2, 2, 0, 3, 3, 1, 0, -2, 1, 2]
# Systhesis
# On Wall:  [1, 0, 0, 1, 1, 3, 2, -1, 3]
# On Wall:  [2, 1, 3, 2, -1, 3, 1, 0, 0]
# Intermolecule:  [3, -1, 1, 1, 0, 2, -1, -2, 1, 2, 0]  Length:  11   [-1, 2, 3, -1, -1, -1, 0, 3, 1, 0, 3]  Length:  11
#  After Intermolecule:  [-1, 0, 3, 1, 0, 3, 3, -1, 1, 1, 0]   [2, -1, -2, 1, 2, 0, -1, 2, 3, -1, -1]
# On Wall:  [3, -1, 1, 1, 0, 2, -1, -2, 1, 2, 0]
# Systhesis
# On Wall:  [3, 3, -2, 0, 2, -1, 3, 2, 0, -1, 1, 0]
# On Wall:  [3, 0, -2, 0, 2, -1, 0, 2, 0, 2, 1, 0]
# On Wall:  [0, 3, 1, 0, -2, -1, 0, 2, 3, 3]
# On Wall:  [0, -2, 0, 3, -1, 3, 2, 0, 2, 1, 0, 3]
# On Wall:  [2, 3, -2, 0, 2, 0, 3, 2, 3, 2, 1, 0]
# On Wall:  [1, 0, 0, 1, 1, 2, 2, -1, 3]
# Intermolecule:  [2, -1, 2, 2, -1, 3, 2, 0, 2, 1, 0, 3]  Length:  12   [0, 3, 3, 1, 0, 1, 3, 2, 2, 2, 2]  Length:  11
#  After Intermolecule:  [3, 2, 2, 2, 2, 2, -1, 2, 2, -1, 3, 2]   [0, 2, 1, 0, 0, 3, 3, 1, 0, 1, 3]
# On Wall:  [0, 3, 3, -2, 0, -1, -1, 3, 2, 0, 2, 1]
# Systhesis
# Systhesis
# On Wall:  [0, 3, 1, 0, 3, -1, 2, 3, -1, -1, -1]
# On Wall:  [2, 2, 0, 2, 0, 2, 3, 1, 0, 2, 3]
# On Wall:  [2, 0, 1, 3, 0, 0, 2, 0, 0, -2, 3]
# On Wall:  [2, 2, 2, 0, 2, 3, 1, 0, -2, 1, 2]
# On Wall:  [2, -1, 3, 1, 0, 1, 1, 1, 2]
# Decomposition
# On Wall:  [3, 1, 1, 1, 0, 2, -1, -2, 1, 2, 0]
# On Wall:  [3, -1, 3, 0, 2, 0, 1, 2, 0, 2]
# Systhesis
# On Wall:  [1, 0, 0, 3, 1, 2, 2, -1, 3]
# On Wall:  [0, 2, 0, -1, 1, 3, 2, 1, 2, 3, 1]
# Systhesis
# On Wall:  [2, 0, 3, 3, 2, 2, 3, 0, 3, 3, 0, 3]
# On Wall:  [0, 3, -2, 0, 1, 3, 2, 2, 2, 2, 0]
# Intermolecule:  [-1, 2, 3, -1, -1, -1, 0, 3, 1, 0, 3]  Length:  11   [2, 2, 2, 2, 0, 3, 3, 1, 0, 1, 3]  Length:  11
#  After Intermolecule:  [0, 3, 1, 0, 3, 2, 0, 3, -1, 2, 3]   [3, 1, 0, 1, 3, -1, -1, -1, 2, 2, 2]
# On Wall:  [0, 0, 1, 1, 2, 2, 1, 2, 1]
# Decomposition
# On Wall:  [2, 0, 1, 1, 2, 3, 0, 2, -1, 2, 3, 2]
# On Wall:  [2, 2, 0, 2, 0, 2, 3, 2, 0, 2, 3]
# On Wall:  [1, 0, 0, 3, 1, 2, 2, -1, 3]
# On Wall:  [2, -1, -2, 1, 2, 0, 3, -1, 0, 1, 0]
# Systhesis
# On Wall:  [-2, 3, 3, 2, 0, 2, 0, 0, 1, 2, 2, 1]
# On Wall:  [2, 2, 0, 2, 0, 2, 3, -1, 0, 2, 3]
# On Wall:  [2, 3, 1, 0, 3, -1, 2, 3, -1, -1, -1]
# Intermolecule:  [2, -1, 2, 2, -1, 3, 2, 0, 2, 1, 0, 3]  Length:  12   [0, 3, 3, 1, 0, 1, 3, 2, 2, 2, 2]  Length:  11
#  After Intermolecule:  [1, 0, 3, 1, 3, 2, 2, 2, -1, 2, 2, -1]   [2, 2, 3, 2, 0, 2, 0, 3, 3, 1, 0]
# Systhesis
# On Wall:  [3, 2, 2, 2, 3, 0, 3, 3, 1, 0, 1]
# Systhesis
# Decomposition
# On Wall:  [3, -2, 0, 2, -1, 3, 2, 0, 2, 1, 0, 1]
# Systhesis
# On Wall:  [0, 3, 2, 2, 3, 3, 2, 2, -2, 0, 3]
# On Wall:  [2, 0, 1, 3, 3, 0, 2, 0, 0, -2, 3]
# On Wall:  [3, 2, -2, 0, 1, 1, 2, 2, 1, 2]
# On Wall:  [2, 2, 0, 2, 0, 2, 3, -1, 0, 2, 3]
# On Wall:  [2, -1, 2, 2, 0, 2, 1, 0, 3, 3, -2, 0]
# On Wall:  [3, 1, 1, 1, 0, 2, -1, -2, 1, 2, 0]
# On Wall:  [2, 0, 2, 1, 0, 3, 3, -2, 0, 0, -1, 3]
# On Wall:  [2, 2, 0, 2, 1, 0, 3, 0, -2, 0, 2, -1]
# Intermolecule:  [3, 2, 2, 3, 3, 2, 2, -2, 0, 3, 0]  Length:  11   [2, 2, 3, 2, -1, 3, 1, 0, 0]  Length:  9
#  After Intermolecule:  [3, 3, 2, 2, -2, 0, 3, 0, 2, 3, 3]   [2, -1, 3, 1, 0, 0, 2, 2, 2]
# Systhesis
# On Wall:  [2, 0, 2, 1, 0, 3, 3, -2, 0, 0, -1, 3]
# On Wall:  [3, 2, 2, 2, 2, 0, 3, 3, 1, 0, 1]
# Systhesis
# On Wall:  [0, 3, 2, 2, 3, 3, 2, 2, -2, 0, 3]
# On Wall:  [0, 3, -1, 1, 1, 0, 2, -1, -2, 1, 2]
# Decomposition
# Decomposition
# On Wall:  [-2, 1, 2, -1, 3, 2, 0, 2, 1, 0, 3, 3]
# Intermolecule:  [-1, 2, 3, -1, -1, -1, 0, 3, 1, 0, 3]  Length:  11   [2, -1, 3, 2, 0, 2, 1, 0, 3, 3, -2, 0]  Length:  12
#  After Intermolecule:  [3, -2, -1, 2, 3, -1, -1, -1, 0, 3, 1]   [0, 0, 3, 2, -1, 3, 2, 0, 2, 1, 0, 3]
# On Wall:  [2, 2, 3, 1, 0, 1, 1, 1, 2]
# On Wall:  [0, 2, 3, -2, 3, 3, 1, 0, 3, 3]
# On Wall:  [1, 3, 2, -1, 3, 1, 0, 0, 1]
# On Wall:  [3, -2, 0, 2, -1, 3, 2, 0, 2, 1, 0, 1]
# On Wall:  [0, 2, -1, -2, 1, 2, 0, 3, -1, 0, 1]
# On Wall:  [0, 2, -1, -2, 1, 2, 0, 3, -1, 0, 1]
# On Wall:  [0, 2, -2, 0, 1, 3, 2, 2, 2, 2, 0]
# On Wall:  [0, -1, 2, 2, 0, 2, 1, 0, 3, 3, -2, 0]
# On Wall:  [0, 3, 3, -2, 0, -1, -1, 3, 2, 3, 2, 1]
# Decomposition
# On Wall:  [2, 3, -2, 0, 2, 0, 3, 2, 3, 0, 1, 0]
# On Wall:  [1, 0, 0, 3, -2, 0, 2, -1, 3, 2, 0, 2]
# On Wall:  [2, 3, -2, 0, 2, -1, 3, 2, 0, -1, 1, 0]
# On Wall:  [1, 3, 2, -1, 3, 1, 0, 0, 2]
# On Wall:  [2, 2, 3, 2, -1, 3, 1, 0, 0]
# Systhesis
# On Wall:  [0, 3, 1, 0, -2, -1, 0, 2, 0, 3]
# Decomposition
# Decomposition
# Systhesis
# Intermolecule:  [3, -1, 0, 1, 0, 2, -1, -2, 1, 2, 0]  Length:  11   [3, 3, 1, 0, 1, 3, 2, 2, 2, 2, 0]  Length:  11
#  After Intermolecule:  [2, -1, -2, 1, 2, 0, 3, 1, 0, 1, 3]   [3, 2, 2, 2, 2, 0, -1, 0, 1, 0, 3]
# On Wall:  [2, 2, 0, 2, 0, 2, 3, 1, 0, 2, 3]
# Intermolecule:  [2, 0, 1, 3, 3, 0, 2, 0, 0, -2, 3]  Length:  11   [3, 2, 2, 3, 3, 2, 2, -2, 0, 3, 0]  Length:  11
#  After Intermolecule:  [-2, 3, -2, 0, 2, 0, 1, 3, 3, 0, 2]   [3, 0, 0, 0, 3, 2, 2, 3, 3, 2, 2]
# On Wall:  [0, 2, 2, 0, 2, 3, 1, 0, -2, 1, 2]
# On Wall:  [0, 2, -1, 3, 2, 0, 2, 1, 0, 3, 3, -2]
# On Wall:  [3, -1, 3, 0, 2, 0, 1, 2, 0, 2]
# On Wall:  [0, 3, 3, -2, 0, -1, -1, 3, 2, 3, 2, 2]
# On Wall:  [0, 2, -2, 0, 1, 3, 2, 2, 2, 2, 0]
# Intermolecule:  [1, 2, 0, 3, 1, 2, 2, -1, 3]  Length:  9   [3, 2, 2, 3, 3, 2, 2, -2, 0, 3, 0]  Length:  11
#  After Intermolecule:  [-2, 0, 1, 2, 0, 3, 1, 2, 2]   [3, 0, -1, 3, 3, 2, 2, 3, 3, 2, 2]
# On Wall:  [0, 2, 0, 2, 0, 2, 3, 1, 0, 2, 3]
# On Wall:  [0, 2, 0, 2, 0, 2, 1, 1, 0, 2, 3]
# On Wall:  [3, -2, 0, 2, -1, 3, 2, 0, 2, 1, 0, 1]
# On Wall:  [1, 3, 2, 2, 2, 2, 2, 3, 3, 1, 1]
# On Wall:  [1, 2, 1, 2, 2, 2, -1, 3, 1, 2]
# On Wall:  [3, 2, -1, 3, 1, 0, 0, 1, 1]
# On Wall:  [0, 1, 1, 1, 3, 0, 3, 3, 0, -1, 3, 3]
# Systhesis
# On Wall:  [-2, 3, 2, -1, 3, 1, 0, 0, 2]
# On Wall:  [1, 3, 1, 0, -2, -1, 0, 2, 0, 3]
# Intermolecule:  [3, 3, 1, 0, 1, 3, 2, 2, 2, 2, 0]  Length:  11   [-2, 2, 2, -1, 3, 2, 0, 2, 1, 0, 3, 3]  Length:  12
#  After Intermolecule:  [0, 3, 3, 3, 1, 0, 1, 3, 2, 2, 2]   [3, 2, 0, -2, 2, 2, -1, 3, 2, 0, 2, 1]
# On Wall:  [2, 0, 3, 3, 2, 2, 3, 0, 0, 3, 0, 3]
# On Wall:  [0, 2, -1, -2, 1, 2, 0, 3, -1, 0, 1]
# On Wall:  [0, 3, -1, 0, 2, -1, 2, 2, 0, 2, 1, 3]
# On Wall:  [2, -1, -2, 1, 2, 0, 3, -1, 0, 1, 0]
# On Wall:  [2, -2, 0, 3, 0, 3, 2, 2, 3, 3, 2]
# Decomposition
# Systhesis
# On Wall:  [3, -1, 2, 3, -1, -1, -1, 0, 3, 1, 0]
# On Wall:  [0, 2, -1, -2, 1, 2, 0, 3, -1, 0, 1]
# On Wall:  [0, 2, 0, 0, 1, 3, 2, 1, 2, 3, 1]
# Intermolecule:  [1, 2, 0, 3, 1, 2, 2, -1, 3]  Length:  9   [0, 2, -1, -2, 1, 2, 0, 3, -1, 0, 1]  Length:  11
#  After Intermolecule:  [3, -1, 1, 2, 0, 3, 1, 2, 2]   [0, 1, -1, 3, 0, 2, -1, -2, 1, 2, 0]
# Decomposition
# On Wall:  [1, 3, 1, 0, -2, -1, 0, 2, 0, 3]
# Systhesis
# On Wall:  [2, 2, 3, 2, -1, 3, 1, 0, 0]
# On Wall:  [0, 2, 1, 0, 3, 3, -2, 0, 2, -1, 3, 2]
# Systhesis
# Intermolecule:  [0, 2, -1, -2, 1, 2, 0, 3, -1, 0, 1]  Length:  11   [0, 3, -1, 1, 1, 0, 2, -1, -2, 1, 2]  Length:  11
#  After Intermolecule:  [-1, -2, 1, 2, 0, 2, -1, -2, 1, 2, 0]   [3, -1, 0, 1, 0, 3, -1, 1, 1, 0, 2]
# On Wall:  [0, 1, 1, 1, 3, 0, 3, 3, 0, -1, 3, 3]
# Intermolecule:  [3, 3, 1, 0, 1, 3, 2, 2, 2, 2, 0]  Length:  11   [0, 0, 1, 1, 2, 2, 1, 2, 1]  Length:  9
#  After Intermolecule:  [2, 2, 0, 1, 2, 3, 3, 1, 0, 1, 3]   [1, 2, 2, 0, 0, 1, 1, 2, 2]
# On Wall:  [0, 2, -1, -2, 1, 2, 0, 3, -1, 0, 1]
# On Wall:  [2, 2, 3, 2, -1, 3, 1, 3, 0]
# Intermolecule:  [2, 0, 3, 3, 2, 2, 3, 0, 0, 3, 2, 3]  Length:  12   [0, 2, -1, -2, 1, 2, 0, 3, -1, 0, 1]  Length:  11
#  After Intermolecule:  [3, 2, 3, -1, -2, 1, 2, 0, 3, -1, 2, 0]   [0, 1, 3, 3, 2, 2, 3, 0, 0, 0, 2]
# On Wall:  [0, 3, 3, -2, 1, -1, -1, 3, 2, 3, 2, 2]
# On Wall:  [3, 2, -1, 3, 1, 0, 0, 2, 1]
# Systhesis
# On Wall:  [3, -1, 0, 0, -1, 2, 1, 3, 3, 3, 2, -2]
# On Wall:  [2, 1, 1, 0, -2, 3, 3, 3, 2, 2, 3]
# Systhesis
# On Wall:  [0, 2, -1, -2, 1, 2, 0, 3, -1, 0, 1]
# On Wall:  [3, 1, 0, 0, -1, 2, 1, 3, 3, 3, 2, -2]
# Intermolecule:  [2, -1, 3, 2, 0, 2, 1, 0, 3, 3, -2, 0]  Length:  12   [3, 2, 2, 3, 3, 2, 2, -2, 0, 3, 0]  Length:  11
#  After Intermolecule:  [0, 3, 0, 2, -1, 3, 2, 0, 2, 1, 0, 3]   [3, -2, 3, 2, 2, 3, 3, 2, 2, -2, 0]
# On Wall:  [3, -2, 0, 2, -1, 3, 2, 0, 2, 1, 0, 1]
# On Wall:  [2, 1, 1, 0, -2, 3, 3, 3, 2, 0, 3]
# On Wall:  [3, 2, 2, 2, 2, 0, 3, 3, 1, 0, 1]
# Systhesis
# Systhesis
# On Wall:  [3, 0, 1, 0, 3, 2, 3, -2, 3, -2, 3, 1]
# On Wall:  [-2, 2, 2, -1, 3, 2, 0, 2, 1, 0, 3, 3]
# On Wall:  [1, 0, 1, 0, 3, 2, 3, -2, 3, -2, 3, 1]
# On Wall:  [0, 2, -1, 3, 2, 0, 2, 1, 0, 3, 3, -2]
# On Wall:  [2, 2, -1, 3, 2, 0, 2, 1, 0, 3, 3, -2]
# On Wall:  [2, 1, 1, 0, -2, 3, 3, 3, 2, 0, 3]
# On Wall:  [1, 0, 1, 0, 3, 2, 3, -2, 3, 1, 3, 1]
# Systhesis
# On Wall:  [3, -2, 0, 2, -1, 3, 2, 0, 2, 1, 3, 1]
# On Wall:  [1, 2, 2, 1, -2, 3, 3, 2, 3, 2, 0, 0]
# On Wall:  [2, 3, -2, 0, 2, -1, 3, 2, 0, -1, -2, 0]
# On Wall:  [3, -1, 3, 0, 2, 0, 1, 2, 0, 2]
# On Wall:  [2, 2, 2, 2, 0, 3, 3, 1, 0, 1, 3]
# On Wall:  [1, 3, 1, 0, -2, -1, 0, 2, 0, 3]
# Decomposition
# Systhesis
# On Wall:  [0, 2, 3, 1, 0, 1, 1, 1, 2]
# On Wall:  [0, 3, -1, 0, 2, -1, 2, 2, 0, 2, 1, 3]
# On Wall:  [0, 0, 1, 1, 2, 2, 1, 2, 1]
# On Wall:  [0, 3, 2, 2, 3, 3, 2, 2, -2, 0, 3]
# On Wall:  [2, -1, 2, 2, -1, 3, 2, 0, 2, 1, 0, 3]
# On Wall:  [2, 0, 3, 3, 2, 2, 3, 0, 0, 3, 2, 3]
# On Wall:  [1, 0, 2, -1, -2, 1, 2, 0, 3, -1, 0]
# On Wall:  [0, -1, 2, 2, 1, 2, 1, 0, 3, 3, -2, 0]
# Systhesis
# On Wall:  [3, 3, 1, 0, 1, 3, 2, 2, 2, 2, 0]
# On Wall:  [0, 2, -1, -2, 1, 2, 0, 3, -1, 0, 3]
# On Wall:  [-2, 2, 2, -1, 3, 3, 0, 2, 1, 0, 3, 3]
# Decomposition
# On Wall:  [2, 2, 3, 2, -1, 3, 1, 3, 0]
# Decomposition
# On Wall:  [-1, -1, 0, 0, 3, 1, 0, 3, -1, 2, 3]
# Systhesis
# On Wall:  [0, 2, 3, 2, 0, 2, 1, 1, 0, 2, 3]
# Decomposition
# On Wall:  [3, 3, 1, 0, 1, 3, 2, 2, 2, 2, 2]
# On Wall:  [0, 2, -1, 3, 3, 0, 2, 1, 0, 3, 3, -2]
# On Wall:  [2, 2, 2, 2, 0, 3, 3, 1, 0, 1, 3]
# On Wall:  [0, 2, 3, 3, 0, 2, 1, 1, 0, 2, 3]
# On Wall:  [0, 2, -1, -2, 1, 2, 0, 3, -1, 0, 1]
# Decomposition
# On Wall:  [0, 2, -2, 0, -2, 3, 2, 2, 2, 2, 0]
# On Wall:  [0, -1, 3, -2, 3, 3, 1, 0, 3, 3]
# On Wall:  [1, 2, 0, 3, 1, 2, 2, -1, 3]
# On Wall:  [2, -2, 0, 3, -1, 3, 2, 0, 2, 1, 0, 3]
# On Wall:  [-2, 3, 2, -1, 3, 1, 0, 0, 3]
# On Wall:  [1, 2, 2, 1, -2, 3, 3, 2, 3, 2, 0, 0]
# On Wall:  [1, 2, 0, 3, 1, 2, 2, -1, 0]
# On Wall:  [0, 2, 0, 0, 1, 3, 2, 1, 2, 3, 1]
# On Wall:  [0, 2, 3, 1, 0, 1, 1, 1, 2]
# On Wall:  [0, 3, -1, 0, 2, -1, 2, 2, 0, -1, 1, 3]
# On Wall:  [1, 2, 1, 2, 2, 2, -1, 1, 1, 2]
# On Wall:  [1, -1, 1, 2, 2, 2, -1, 1, 1, 2]
# On Wall:  [0, 2, -1, -2, 1, 2, 0, 3, -1, 0, 1]
# On Wall:  [1, 0, 2, 1, -2, 3, 3, 2, 3, 2, 0, 0]
# On Wall:  [2, 3, -2, 0, 2, -1, 3, 2, 0, -1, -2, 1]
# On Wall:  [2, 3, 1, 0, 3, -1, 2, 3, -1, -1, -1]
# Systhesis
# On Wall:  [3, 3, 1, 0, 1, 3, 2, 2, 2, 2, 0]
# Systhesis
# Intermolecule:  [-1, 3, 1, 0, 0, 1, 1, 3, 2]  Length:  9   [3, 3, 1, 0, 1, 3, 2, 2, 2, 2, 2]  Length:  11
#  After Intermolecule:  [1, 3, 2, 1, 3, -1, 3, 1, 0]   [2, 2, 2, 2, 2, 0, 1, 3, 3, 1, 0]
# Systhesis
# On Wall:  [-1, 3, 2, 0, 3, 1, 3, 1, 0, -2]
# On Wall:  [0, 2, 1, 0, 3, 0, -2, 0, 2, -1, 3, 2]
# On Wall:  [-1, 3, 2, 0, 3, 1, 3, 1, 0, -2]
# On Wall:  [1, 0, 0, 3, -2, 0, 2, -1, 3, 2, 1, 2]
# On Wall:  [3, 1, 0, 0, -1, 2, 1, 3, 1, 3, 2, -2]
# On Wall:  [0, 2, 3, 1, 0, 1, 1, 1, 3]
# On Wall:  [2, 2, -1, 3, 2, 0, 0, 1, 0, 3, 3, -2]
# On Wall:  [1, 0, 2, -1, -2, 1, 2, 0, 3, -1, 0]
# On Wall:  [1, 0, 0, 3, -2, 0, 2, -1, 3, 2, 1, 2]
# On Wall:  [3, 3, 1, 0, 1, 3, 2, 2, 2, 2, 2]
# Intermolecule:  [2, -2, 0, 3, 0, 3, 2, 2, 3, 3, 2]  Length:  11   [1, 0, 2, -1, -2, 1, -1, 0, 3, -1, 0]  Length:  11
#  After Intermolecule:  [3, 2, 0, 2, -1, -2, 1, -1, 0, 3, 2]   [-1, 0, -2, 0, 3, 0, 3, 2, 2, 3, 1]
# On Wall:  [2, 2, -2, 0, -2, 3, 2, 2, 2, 2, 0]
# Systhesis
# On Wall:  [1, 0, 0, 3, 0, 0, 2, -1, 3, 2, 1, 2]
# On Wall:  [0, 3, 3, -2, 1, -1, -1, 3, -1, 3, 2, 2]
# On Wall:  [2, 0, 3, 2, 2, 2, 3, 0, 0, 3, 2, 3]
# On Wall:  [1, 0, 1, 2, 2, 2, -1, 1, 1, 2]
# On Wall:  [3, -2, 0, 2, 1, 3, 2, 0, 2, 1, 3, 1]
# Systhesis
# On Wall:  [3, 0, -2, 0, 2, -1, 0, 2, 0, 2, 1, 0]
# Systhesis
# Intermolecule:  [3, 2, 2, 2, 2, 0, 3, 3, 1, 0, 1]  Length:  11   [2, 0, 3, 3, 1, 0, 1, 3, 2, 2, 2]  Length:  11
#  After Intermolecule:  [0, 3, 3, 1, 0, 1, 3, 1, 3, 2, 2]   [0, 1, 3, 2, 2, 2, 2, 2, 2, 0, 3]
# On Wall:  [-1, 3, 1, 0, 0, 1, 1, 3, 2]
# Systhesis
# Systhesis
# On Wall:  [1, 0, 3, 3, 0, 0, 2, -1, 3, 2, 1, 2]
# On Wall:  [0, 3, -1, 1, 1, 0, 2, -1, -2, 1, 2]
# On Wall:  [2, -2, 0, 3, 0, 3, 2, 0, 2, 1, 0, 3]
# On Wall:  [2, -1, -2, 1, 2, 0, 3, -1, 0, 1, 0]
# Decomposition
# On Wall:  [2, -1, 2, 2, -1, 3, 2, 0, 2, 1, 0, 3]
# Systhesis
# On Wall:  [0, 3, 2, 2, 3, 3, 2, 2, -2, 0, 3]
# On Wall:  [2, 2, -2, 1, -2, 3, 2, 2, 2, 2, 0]
# On Wall:  [2, 2, 2, 2, 0, 3, 3, 1, 0, 1, 3]
# On Wall:  [1, 3, 2, 3, 2, 2, 2, 3, 3, 1, 1]
# On Wall:  [2, -2, 0, 3, 0, 3, 2, 2, 3, 3, 2]
# Decomposition
# On Wall:  [3, 1, 0, 3, -1, 2, 3, -1, -1, -1, 0]
# On Wall:  [2, -1, 3, 2, 0, 2, 1, 0, 3, 3, -2, 0]
# On Wall:  [0, 0, 1, 1, 2, 2, 1, 2, -2]
# On Wall:  [3, -1, 0, 1, 0, 2, -1, -2, 1, 2, 0]
# Systhesis
# On Wall:  [3, 1, 1, 1, 0, 2, -1, -2, 1, 2, 0]
# Intermolecule:  [1, 0, 2, -1, -2, 1, -1, 0, 3, -1, 0]  Length:  11   [3, 3, 1, 1, 1, 3, 2, 2, 2, 2, 2]  Length:  11
#  After Intermolecule:  [3, 2, 2, 2, 2, 2, 1, 0, 2, -1, -2]   [1, -1, 0, 3, -1, 0, 3, 3, 1, 1, 1]
# On Wall:  [3, 3, 1, 1, 1, 3, 2, 2, 2, 2, 2]
# On Wall:  [3, 2, 0, 0, 1, 1, 2, 2, 1, 2]
# On Wall:  [0, 3, -1, 0, 2, -1, 2, 2, 0, 0, 1, 3]
# Systhesis
# Decomposition
# Decomposition
# On Wall:  [0, 2, 1, 0, 1, 3, 2, 1, 2, 3, 1]
# Intermolecule:  [2, 2, 2, 2, 0, 3, 3, 1, 0, 1, 3]  Length:  11   [0, 3, -1, 1, 2, 0, 2, -1, -2, 1, 2]  Length:  11
#  After Intermolecule:  [1, 3, 0, 2, -1, -2, 2, 2, 2, 2, 0]   [1, 2, 3, 3, 1, 0, 0, 3, -1, 1, 2]
# On Wall:  [-1, 3, 1, 0, 0, 1, 1, 3, 2]
# Systhesis
# On Wall:  [0, 2, -1, -2, 1, 2, 0, 3, -1, 0, 1]
# On Wall:  [2, 2, 2, 2, 0, 3, 3, 1, 0, 1, 3]
# On Wall:  [3, 3, -1, 0, 2, -1, 2, 2, 0, 0, 1, 3]
# Systhesis
# On Wall:  [0, 2, 3, 0, 0, 2, 1, 1, 0, 2, 3]
# On Wall:  [2, -2, 0, 3, 0, 3, 2, 0, 2, 1, 0, 3]
# On Wall:  [0, 2, 2, 0, 2, 1, 1, 0, -2, 1, 2]
# Decomposition
# On Wall:  [-1, 3, 2, 0, 3, 1, 3, 1, 0, -2]
# Decomposition
# On Wall:  [-2, 2, 0, -1, 3, 3, 0, 2, 1, 0, 3, 3]
# On Wall:  [-1, -1, 0, 0, 3, 1, 0, 3, -1, 2, 1]
# Systhesis
# Systhesis
# On Wall:  [-2, 3, 2, -1, 3, 1, 0, 0, 2]
# Intermolecule:  [0, 3, 2, 2, 3, 3, 2, 2, -2, 0, 3]  Length:  11   [1, 0, 2, 1, -2, 0, 3, 2, 3, 2, 0, 0]  Length:  12
#  After Intermolecule:  [0, 2, 1, -2, 0, 3, 2, 3, 2, 0, 0]   [0, 3, 2, 2, 3, 3, 2, 2, -2, 0, 3, 1]
# Decomposition
# On Wall:  [0, 3, 2, 2, 3, 3, 2, 2, -2, 0, 3]
# On Wall:  [0, -1, 3, -2, 3, 3, 2, 0, 3, 3]
# On Wall:  [2, 2, 1, 0, 1, 3, 2, 1, 2, 3, 1]
# Decomposition
# On Wall:  [3, 3, 1, 1, 1, 3, 2, -1, 2, 2, 2]
# On Wall:  [2, 3, 1, 0, 3, -1, 3, 3, -1, -1, -1]
# Systhesis
# Systhesis
# On Wall:  [3, 2, 2, 2, 2, 0, 3, 3, 1, 0, 1]
# On Wall:  [0, 3, -1, 1, 2, 0, 2, -1, -2, 1, 2]
# Decomposition
# On Wall:  [3, 0, -1, 3, 1, 0, 0, 2, 1]
# Decomposition
# On Wall:  [2, 1, 1, 0, -2, 3, 3, 3, 0, 0, 3]
# Decomposition
# On Wall:  [3, 2, 1, 1, 0, -2, 3, 3, 3, 0, 0]
# Intermolecule:  [1, 0, 2, 1, -2, 0, 3, 2, 3, 2, 0, 0]  Length:  12   [0, 2, 3, 1, 0, 1, 1, 1, 3]  Length:  9
#  After Intermolecule:  [3, 2, 0, 0, 1, 1, 1, 1, 0, 2, 1, -2]   [3, 0, 3, 2, 0, 2, 3, 1, 0]
# On Wall:  [1, 0, 1, 0, 3, 2, 1, -2, 3, 1, 3, 1]
# On Wall:  [3, 0, -2, 0, 2, -1, 0, 2, 0, 2, 1, 2]
# On Wall:  [0, 2, 2, 0, 2, 1, 1, 0, 0, 1, 2]
# On Wall:  [0, 1, 3, 2, 2, 2, 2, 0, 3, 3, 1]
# Systhesis
# Systhesis
# Intermolecule:  [1, 0, 2, 1, -2, 0, 3, 2, 3, 2, 0, 0]  Length:  12   [0, 3, 1, 3, 1, 0, -2, -1, 3, 2]  Length:  10
#  After Intermolecule:  [2, 3, 2, 0, 0, 1, 0, -2, 1, 0, 2, 1]   [-1, 3, 2, -2, 0, 3, 0, 3, 1, 3]
# On Wall:  [3, 1, 1, 1, 0, 2, 2, -2, 1, 2, 0]
# Decomposition
# On Wall:  [3, 3, 1, 0, 2, -1, 2, 2, 0, 0, 1, 3]
# On Wall:  [0, 2, -1, -2, 1, 2, 0, 3, -1, 0, 1]
# On Wall:  [2, 2, 1, 0, 1, 3, 2, 1, 0, 3, 1]
# Systhesis
# Systhesis
# Systhesis
# Decomposition
# Systhesis
# On Wall:  [3, 2, -2, 1, 0, -2, 3, 3, 3, 0, 0]
# On Wall:  [1, 0, 2, 1, -2, 0, 3, 2, 3, 2, 0, 0]
# Systhesis
# On Wall:  [2, -1, -2, 1, 2, 0, 3, -1, 0, 1, 0]
# Decomposition
# On Wall:  [0, 2, -1, -2, 3, 2, 0, 3, -1, 0, 3]
# On Wall:  [2, 3, -2, 3, 2, 0, 3, 2, 3, 0, 1, 0]
# On Wall:  [0, 2, -1, -2, 3, 2, 0, 3, -1, 0, 3]
# On Wall:  [0, 1, 1, 1, 3, 0, 3, 3, 0, -1, 1, 3]
# On Wall:  [-2, 3, 2, -1, 3, -2, 0, 0, 2]
# On Wall:  [0, 0, -1, -2, 3, 2, 0, 3, -1, 0, 3]
# On Wall:  [0, 2, -1, -2, 1, 2, 0, 3, -1, 0, 1]
# On Wall:  [2, -1, 3, 2, 0, 2, -2, 0, 3, 3, -2, 0]
# Decomposition
# On Wall:  [0, 2, -1, -2, 1, 2, 0, 3, -1, 0, 1]
# On Wall:  [3, 0, -1, 3, 1, 0, 0, 2, 1]
# On Wall:  [2, -2, 0, 3, 0, 3, 2, 2, 3, 3, 2]
# On Wall:  [-2, 2, 0, -1, 3, 3, 0, 2, 1, 1, 3, 3]
# Decomposition
# On Wall:  [3, 2, -2, 1, 0, -2, 3, 3, 3, 0, 0]
# Systhesis
# On Wall:  [2, 2, 0, 2, 1, 0, 3, 0, -2, 0, 2, -1]
# Intermolecule:  [3, 2, 2, 3, 3, 2, 2, -2, 0, 3, 0]  Length:  11   [2, 2, 1, 2, 3, 2, 0, 3, 1, 1]  Length:  10
#  After Intermolecule:  [0, 1, 1, 3, 2, 2, 3, 3, 2, 2, -2]   [0, 3, 2, 2, 1, 2, 3, 2, 0, 3]
# On Wall:  [-2, 3, 2, -1, 3, -2, 0, 0, 0]
# On Wall:  [2, -2, 0, 3, 0, 3, 2, 2, 3, 3, 2]
# On Wall:  [3, 0, -1, 3, 1, 1, 0, 2, 1]
# On Wall:  [3, 0, -1, 3, 1, -2, 0, 2, 1]
# On Wall:  [0, 2, 3, 2, 2, 2, 2, 0, 3, 3, 1]
# Decomposition
# Decomposition
# On Wall:  [1, 0, 3, -1, 2, 3, -1, -1, -1, 0, 3]
# On Wall:  [-1, 3, 1, 1, 0, 1, 1, 3, 2]
# On Wall:  [2, -2, 0, 3, 0, 3, 2, 2, 3, 3, 2]
# On Wall:  [2, -2, 2, 3, 0, 3, 2, 2, 3, 3, 2]
# Decomposition
# On Wall:  [2, -2, 0, 3, 1, 3, 2, 2, 3, 3, 2]
# On Wall:  [2, 2, 1, 0, 1, 2, 2, 1, 0, 3, 1]
# On Wall:  [2, 0, 1, 3, 3, 0, 2, 0, 0, -2, 3]
# On Wall:  [2, 3, -2, 3, 2, 0, 3, 2, 3, 0, 3, 0]
# On Wall:  [2, 1, 3, 2, 0, 2, -2, 0, 3, 3, -2, 0]
# On Wall:  [-1, -1, 2, 2, -1, 3, 2, 0, 2, 1, 0, 3]
# On Wall:  [-1, 3, 2, 0, 3, 1, 3, 1, 0, -2]
# On Wall:  [2, 3, 2, 0, 3, 1, 1, 2, 2, 1]
# Systhesis
# On Wall:  [0, 3, -1, 1, 2, 0, 2, -1, -2, 1, 3]
# On Wall:  [0, 2, 3, 0, 0, 2, 1, 1, 0, 2, 2]
# On Wall:  [-1, 3, 2, 1, 0, 1, 1, 3, 2]
# On Wall:  [3, -2, 2, 3, 0, 3, 2, 2, 3, 3, 2]
# Systhesis
# On Wall:  [2, 2, 2, 2, 0, 3, 3, 1, 0, 1, 3]
# Intermolecule:  [0, 3, -1, 1, -1, 0, 2, -1, -2, 1, 3]  Length:  11   [3, -1, 3, 0, 2, 0, -2, 2, 0, 2]  Length:  10
#  After Intermolecule:  [1, -1, 0, 2, -1, -2, 1, 3, 3, -1, 3]   [0, 2, 0, -2, 2, 0, 2, 0, 3, -1]
# On Wall:  [0, 0, -1, -2, 1, 2, 0, 3, -1, 0, 3]
# Systhesis
# Intermolecule:  [0, 3, 2, 1, 1, 0, -2, 3, 3, 3, 0]  Length:  11   [3, 2, -2, 1, 0, -2, 3, 3, 3, 0, 0]  Length:  11
#  After Intermolecule:  [3, 3, 0, 0, 0, 3, 2, 1, 1, 0, -2]   [3, 3, 3, 0, 3, 2, -2, 1, 0, -2, 3]
# Decomposition
# Systhesis
# Systhesis
# On Wall:  [2, 3, -1, 3, 2, 0, 0, 1, 0, 3, 3, -2]
# On Wall:  [-2, 3, 2, -1, 3, -2, 0, 0, 0]
# On Wall:  [0, 2, 3, 0, 0, 2, 1, 1, 0, 2, 2]
# Decomposition
# On Wall:  [2, -1, -2, 1, 2, 0, 3, -1, 0, 1, 0]
# Intermolecule:  [2, 1, 1, 0, -2, 3, 3, 3, 0, 0, 3]  Length:  11   [3, 2, 3, 2, 0, 0, 1, 2, 2, 1, -2, 3]  Length:  12
#  After Intermolecule:  [-2, 3, 3, 3, 0, 0, 3, 3, 2, 2, 1]   [0, 0, 1, 2, 2, 1, -2, 3, 1, 0, 3, 2]
# On Wall:  [1, 0, 2, -1, -2, 1, -1, 0, 3, -1, 0]
# On Wall:  [3, 2, -2, 1, 0, -2, 3, 3, 3, 0, 0]
# On Wall:  [3, 1, 0, 3, -1, 2, 3, -1, 0, -1, 0]
# On Wall:  [2, -2, 0, 3, 1, 3, 2, 2, 3, 3, 2]
# On Wall:  [0, 3, 2, 2, 3, 3, 2, 2, -2, 0, 3]
# On Wall:  [1, 3, 2, 0, 2, 2, 2, 3, 3, 1, 1]
# On Wall:  [0, 0, 2, 1, 0, 3, 3, -2, 0, 0, -1, 3]
# On Wall:  [0, 0, 1, -2, 1, 2, 0, 3, -1, 0, 3]
# Systhesis
# Intermolecule:  [2, 3, -2, 0, 2, -1, 3, 2, 0, 0, -2, 1]  Length:  12   [2, 2, 1, 2, 3, 2, 0, 3, 1, 1]  Length:  10
#  After Intermolecule:  [-2, 1, 1, 1, 2, 3, -2, 0, 2, -1, 3, 2]   [0, 0, 2, 2, 1, 2, 3, 2, 0, 3]
# On Wall:  [0, 2, 3, 1, 0, 1, 1, 1, 3]
# Decomposition
# Decomposition
# On Wall:  [2, 0, 3, 2, -1, 2, 3, 0, 0, 3, 2, 3]
# Decomposition
# Systhesis
# On Wall:  [-1, -1, 0, 3, 1, 0, 3, -1, 2, 3, -1]
# On Wall:  [1, 0, 2, -1, -2, 1, -1, 0, 3, -1, 0]
# On Wall:  [0, 2, 2, 1, 2, 1, 1, 0, 0, 1, 2]
# On Wall:  [0, 1, 1, 1, 3, 0, 3, 3, 0, -1, 1, 3]
# On Wall:  [2, -2, 0, 3, 1, 1, 2, 2, 3, 3, 2]
# On Wall:  [3, -2, 2, 3, 0, 3, 2, -1, 3, 3, 2]
# On Wall:  [1, 0, 1, 2, 2, 2, -1, 1, 1, 2]
# Decomposition
# On Wall:  [2, 3, -1, 0, 2, 0, 0, 1, 0, 3, 3, -2]
# Decomposition
# On Wall:  [1, 0, 1, 2, 2, 2, -1, 1, 1, 2]
# On Wall:  [2, 1, 1, 0, -2, 3, 3, 3, 0, 0, 3]
# On Wall:  [2, -2, 0, 3, 0, 3, 2, 0, 2, 3, 0, 3]
# On Wall:  [2, 3, -2, 2, 2, 0, 3, 2, 3, 0, 3, 0]
# On Wall:  [1, 0, 0, -1, -2, 1, -1, 0, 3, -1, 0]
# Decomposition
# On Wall:  [2, -1, 0, 1, 0, 2, -1, -2, 1, 2, 0]
# Decomposition
# Decomposition
# Decomposition
# Decomposition
# On Wall:  [3, 2, 2, 2, 2, 0, 3, 3, 1, 0, 1]
# Decomposition
# Decomposition
# Intermolecule:  [2, 0, 3, 1, 1, 2, 2, 1, 2, 3]  Length:  10   [3, 3, -2, 1, 0, -2, 3, 3, 3, 0, 0]  Length:  11
#  After Intermolecule:  [-2, 3, 3, 3, 0, 2, 0, 3, 1, 1]   [0, 2, 2, 1, 2, 3, 3, 3, -2, 1, 0]
# On Wall:  [2, 3, 1, 0, 3, -1, 3, 3, -1, -1, -1]
# On Wall:  [0, 2, -1, -2, 1, 2, 0, 3, -1, 0, 1]
# Decomposition
# Systhesis
# Decomposition
# Intermolecule:  [2, 0, 3, 1, 1, 2, 2, 1, 2, 3]  Length:  10   [1, 2, 0, 3, -1, 0, 1, 0, 2, -1, -2]  Length:  11
#  After Intermolecule:  [1, 2, 3, 2, 0, 3, -1, 0, 1, 2]   [0, 2, -1, -2, 0, 3, 1, 1, 2, 2, 1]
# Systhesis
# On Wall:  [2, 3, 3, 2, 2, -2, 0, 3, 0, 3, 2]
# Intermolecule:  [2, 3, 2, 0, 3, 1, 1, 2, 2, 1]  Length:  10   [2, -2, 0, 3, 1, 1, 2, 2, 3, 3, 2]  Length:  11
#  After Intermolecule:  [1, 0, 3, 1, 1, 2, 2, 3, 2, 3]   [3, 2, 2, 0, 3, 1, 1, 2, 2, 2, -2]
# On Wall:  [2, 3, 3, 2, 2, -2, 0, 3, 0, 3, 2]
# On Wall:  [3, 2, 2, 2, 2, 0, 3, 3, 2, 0, 1]
# On Wall:  [2, 3, 2, 0, 3, 1, 1, 2, 2, 1]
# Systhesis
# On Wall:  [2, 0, 3, 2, -1, 2, 3, 0, 0, 3, 2, 3]
# On Wall:  [2, -2, 0, 3, 0, 3, 2, 0, 2, 3, 0, 3]
# On Wall:  [-1, -1, 0, 3, 1, 0, 1, -1, 2, 3, -1]
# On Wall:  [-1, 3, 1, 3, 1, 1, 0, 1, 0, 3, 2, 1]
# Decomposition
# On Wall:  [1, 0, 1, 3, 0, 0, 2, -1, 3, 2, 1, 2]
# On Wall:  [0, 2, 3, 2, 0, 1, 1, 1, 3]
# On Wall:  [2, 0, 1, 3, 3, 0, 0, 0, 0, -2, 3]
# On Wall:  [3, -2, 2, 3, 0, 3, 2, -1, 3, 3, 2]
# On Wall:  [1, 3, 2, 3, 2, 2, 2, 3, 3, 1, 1]
# Decomposition
# Decomposition
# On Wall:  [3, 2, 2, 2, 2, 0, 0, 3, 2, 0, 1]
# On Wall:  [-2, 2, 2, -1, 3, -2, 0, 0, 0]
# On Wall:  [2, 2, -1, 3, 3, 0, 2, 1, 0, 3, 3, -2]
# On Wall:  [-1, 0, 3, 1, 0, 3, -1, 2, 3, -1, -1]
# Systhesis
# On Wall:  [0, 3, 2, 1, -1, 3, 1, 3, 1, 1, 0, 1]
# Decomposition
# On Wall:  [1, 3, 3, -1, 2, 3, -1, -1, -1, 0, 3]
# Decomposition
# On Wall:  [2, 2, 1, 0, 1, 2, 2, 1, 0, 3, 1]
# Intermolecule:  [2, 2, 0, 2, 1, 0, 3, 0, -2, 0, 2, -1]  Length:  12   [0, 3, 1, 0, 3, -1, 3, 3, -1, -1, -1]  Length:  11
#  After Intermolecule:  [2, 1, 0, 3, 0, -2, 0, 2, -1, 0, 3, 1]   [0, 3, -1, 3, 3, -1, -1, -1, 2, 2, 0]
# On Wall:  [2, 1, 1, 0, -2, 3, 3, 3, 1, 0, 3]
# On Wall:  [3, 3, 0, -1, 1, 3, 0, 1, 1, 1, 3, 0]
# On Wall:  [2, -2, 0, 3, 0, 3, 2, 0, 2, 3, 1, 3]
# Systhesis
# On Wall:  [3, 3, -2, 2, 2, 0, 3, 2, 3, 0, 3, 0]
# On Wall:  [0, 2, 3, 2, 0, 1, 1, 1, 3]
# On Wall:  [2, 1, 1, 0, -2, 3, 3, 3, 1, 1, 3]
# Systhesis
# On Wall:  [2, 3, -1, 0, 2, 0, 0, 1, 0, 3, 3, -2]
# On Wall:  [2, 0, 3, 1, 1, 2, 2, 1, 2, 3]
# On Wall:  [0, 2, 2, 1, 2, 1, 1, 2, 0, 1, 2]
# On Wall:  [1, 0, 1, 3, 0, 0, 2, -1, 3, 2, 1, 3]
# On Wall:  [2, 0, 3, 1, 1, 2, 2, 1, 2, 3]
# On Wall:  [2, 2, -1, 3, 3, 0, 2, 1, 0, 3, 3, -2]
# Decomposition
# On Wall:  [0, 2, -1, -2, 1, 2, 0, 3, -1, 0, 1]
# On Wall:  [2, -2, 3, 1, 0, 0, -1, 2, 1, 3, -2, 3]
# On Wall:  [3, 2, 2, 2, 2, 0, 3, 3, 1, 0, 1]
# On Wall:  [3, 1, 1, 2, 2, 1, 2, 3, 2, 0]
# On Wall:  [2, -2, 0, 3, 0, 3, 2, 0, 2, 3, 1, 3]
# On Wall:  [-1, -1, 0, 0, 3, 1, 0, 3, -1, 2, 1]
# On Wall:  [3, 1, 3, 2, 0, 2, -2, 0, 3, 3, -2, 0]
# On Wall:  [3, 3, -2, 2, 2, 0, 3, 2, 3, 0, 3, 0]
# On Wall:  [1, 2, 2, 3, 2, 2, 2, 3, 3, 1, 1]
# Systhesis
# On Wall:  [2, -2, 0, 3, 1, 1, 2, 2, 3, 3, 2]
# On Wall:  [3, 3, 0, -1, 1, 3, 0, 1, 1, 1, 3, 2]
# On Wall:  [1, 0, 0, 3, 1, 2, 2, -1, 0]
# Decomposition
# Systhesis
# On Wall:  [2, 0, 2, 1, 1, 2, 2, 1, 2, 3]
# On Wall:  [3, 1, 0, 3, -1, 2, 3, -1, 0, -1, 0]
# Decomposition
# On Wall:  [-1, 3, 1, 3, 1, 1, 2, 1, 0, 3, 2, 1]
# Decomposition
# On Wall:  [3, 1, 1, 2, 2, 1, 2, 3, 2, 0]
# Systhesis
# Decomposition
# On Wall:  [1, 2, 2, 1, -2, 3, 3, 2, 3, 2, 0, 0]
# On Wall:  [3, 2, 3, 2, 2, 0, 0, 3, 2, 0, 1]
# Decomposition
# Decomposition
# Intermolecule:  [3, 2, 1, 2, 2, 0, 0, 3, 2, 0, 1]  Length:  11   [-1, 1, 3, 1, 0, 3, -1, 2, 3, -1, -1]  Length:  11
#  After Intermolecule:  [2, 0, 1, 1, 0, 3, -1, 2, 3, 2, 1]   [3, -1, -1, 2, 2, 0, 0, 3, -1, 1, 3]
# Intermolecule:  [1, -2, 3, 3, 2, 3, 2, 0, 0, 1, 2, 2]  Length:  12   [2, -2, 0, 3, 0, 3, 2, 0, 2, 3, 1, 3]  Length:  12
#  After Intermolecule:  [0, 1, 2, 2, 2, 0, 1, -2, 3, 3, 2, 3]   [2, 3, 1, 3, 2, 0, 2, -2, 0, 3, 0, 3]
# Intermolecule:  [1, -2, 3, 3, 2, 3, 2, 0, 0, 1, 2, 2]  Length:  12   [1, 3, 0, 1, 1, 1, 3, 0, 3, 3, 0, -1]  Length:  12
#  After Intermolecule:  [1, 2, 2, 1, 1, 3, 0, 3, 1, -2, 3, 3]   [3, 0, -1, 2, 3, 2, 0, 0, 1, 3, 0, 1]
# On Wall:  [2, 2, 2, 3, 3, 0, 2, 1, 0, 3, 3, -2]
# Systhesis
# On Wall:  [3, 1, -1, 3, 1, -2, 0, 2, 1]
